# %% [markdown]
# # Math Question Answer Verification Competition
#
# ## Starter Code

# %% [markdown]
# Borrowed from [official Unsloth implementation](https://colab.research.google.com/drive/1Ys44kVvmeZtnICzWz0xgpRnrIOjZAuxp?usp=sharing#scrollTo=MKX_XKs_BNZR)

# %%
# %%capture
# This cell will take time
# !pip install unsloth
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# Out:
# Collecting unsloth
#   Downloading unsloth-2024.11.6-py3-none-any.whl.metadata (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 2.4 MB/s eta 0:00:00
# Collecting unsloth-zoo>=2024.11.1 (from unsloth)
#   Downloading unsloth_zoo-2024.11.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (2.5.0+cu121)
# Collecting xformers>=0.0.27.post2 (from unsloth)
#   Downloading xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting bitsandbytes (from unsloth)
#   Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Collecting triton>=3.0.0 (from unsloth)
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from unsloth) (24.2)
# Collecting tyro (from unsloth)
#   Downloading tyro-0.8.14-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: transformers>=4.46.1 in /usr/local/lib/python3.10/dist-packages (from unsloth) (4.46.2)
# Collecting datasets>=2.16.0 (from unsloth)
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unsloth) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unsloth) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.44.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from unsloth) (1.26.4)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.10/dist-packages (from unsloth) (1.1.1)
# Collecting trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 (from unsloth)
#   Downloading trl-0.12.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.13.2)
# Collecting protobuf<4.0.0 (from unsloth)
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (679 bytes)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.26.2)
# Collecting hf-transfer (from unsloth)
#   Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.1->unsloth) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.1->unsloth) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.16.0->unsloth)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (2.32.3)
# Collecting xxhash (from datasets>=2.16.0->unsloth)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.16.0->unsloth)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.16.0->unsloth)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (3.10.10)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unsloth) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth) (0.20.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (13.9.4)
# Collecting torch>=2.4.0 (from unsloth)
#   Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth) (0.16)
# Collecting shtab>=1.5.6 (from tyro->unsloth)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2024.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.16.0->unsloth) (0.2.0)
# Downloading unsloth-2024.11.6-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.0/162.0 kB 4.7 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 16.9 MB/s eta 0:00:00
# Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 39.3 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 10.6 MB/s eta 0:00:00
# Downloading trl-0.12.0-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.2/310.2 kB 14.6 MB/s eta 0:00:00
# Downloading unsloth_zoo-2024.11.5-py3-none-any.whl (31 kB)
# Downloading xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 84.1 MB/s eta 0:00:00
# Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl (906.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 98.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 50.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 12.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.4 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.7 MB/s eta 0:00:00
# Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 8.0 MB/s eta 0:00:00
# Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 69.0 MB/s eta 0:00:00
# Downloading tyro-0.8.14-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.8/109.8 kB 12.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.1 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.9 MB/s eta 0:00:00
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.2 MB/s eta 0:00:00
# Installing collected packages: xxhash, triton, shtab, protobuf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, hf-transfer, fsspec, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, tyro, nvidia-cusolver-cu12, torch, xformers, datasets, bitsandbytes, trl, unsloth-zoo, unsloth
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.6.77
#     Uninstalling nvidia-nvjitlink-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.6.77
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.3.3
#     Uninstalling nvidia-cublas-cu12-12.6.3.3:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.3.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.5.1.17
#     Uninstalling nvidia-cudnn-cu12-9.5.1.17:
#       Successfully uninstalled nvidia-cudnn-cu12-9.5.1.17
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.0+cu121
#     Uninstalling torch-2.5.0+cu121:
#       Successfully uninstalled torch-2.5.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# torchaudio 2.5.0+cu121 requires torch==2.5.0, but you have torch 2.5.1 which is incompatible.
# torchvision 0.20.0+cu121 requires torch==2.5.0, but you have torch 2.5.1 which is incompatible.
# Successfully installed bitsandbytes-0.44.1 datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 hf-transfer-0.1.8 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 protobuf-3.20.3 shtab-1.7.1 torch-2.5.1 triton-3.1.0 trl-0.12.0 tyro-0.8.14 unsloth-2024.11.6 unsloth-zoo-2024.11.5 xformers-0.0.28.post3 xxhash-3.5.0
# Found existing installation: unsloth 2024.11.6
# Uninstalling unsloth-2024.11.6:
#   Successfully uninstalled unsloth-2024.11.6
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-reiwr7nv/unsloth_413fe3f60236435ab2985c101bd1986e
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-reiwr7nv/unsloth_413fe3f60236435ab2985c101bd1986e
#   Resolved https://github.com/unslothai/unsloth.git to commit d8ff860c842095f4729fdd1d5aedf567a9e2c4da
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: unsloth-zoo>=2024.11.1 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.11.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.2)
# Requirement already satisfied: tyro in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.8.14)
# Requirement already satisfied: transformers>=4.46.1 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.46.2)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.44.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.26.4)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.20.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.26.2)
# Requirement already satisfied: hf-transfer in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.8)
# Requirement already satisfied: bitsandbytes>=0.43.3 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.44.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.10.10)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.12.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.20.3)
# Requirement already satisfied: triton in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.0)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.1.1)
# Requirement already satisfied: trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.12.0)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.13.2)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.2)
# Building wheels for collected packages: unsloth
#   Building wheel for unsloth (pyproject.toml) ... done
#   Created wheel for unsloth: filename=unsloth-2024.11.6-py3-none-any.whl size=161268 sha256=be764abb2b7ed76af7b059bd5f9ea5ea05764db9b038a4015a544b35be9a5749
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tcrdyv_5/wheels/ed/d4/e9/76fb290ee3df0a5fc21ce5c2c788e29e9607a2353d8342fd0d
# Successfully built unsloth
# Installing collected packages: unsloth
# Successfully installed unsloth-2024.11.6

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.11.6: Fast Llama patching. Transformers = 4.46.2.
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.564 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.1+cu124. CUDA = 8.0. CUDA Toolkit = 12.4.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/230 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/345 [00:00<?, ?B/s]

# %% [markdown]
# ## Load model and wrap with LoRA adapters

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2024.11.6 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# ## Competition dataset

# %%
# download and load competition dataset

from datasets import load_dataset
dataset = load_dataset("ad6398/nyu-dl-teach-maths-comp")
# print and see dataset
dataset
# Out:
# README.md:   0%|          | 0.00/2.09k [00:00<?, ?B/s]
# train-00000-of-00002.parquet:   0%|          | 0.00/195M [00:00<?, ?B/s]
# train-00001-of-00002.parquet:   0%|          | 0.00/195M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/3.65M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1000000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'is_correct', 'answer', 'solution'],
#         num_rows: 1000000
#     })
#     test: Dataset({
#         features: ['question', 'is_correct', 'answer', 'solution'],
#         num_rows: 10000
#     })
# })

# %%
prompt = """You are a great mathematician and you are tasked with finding if an answer to a given maths question is correct or not. Yout response should be 'True' if correct, otherwise 'False'. Below is Question and Answer.



### Question:
{}

### Answer:
{}

### Explainaition

### Output:
{}"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    question = examples["question"]
    ans       = examples["answer"]
    output      = examples["is_correct"]
    texts = []
    for instruction, input, output in zip(question, ans, output):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        text = prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }

# %%
# Process the training dataset and generate prompt for each datapoint

train_dataset = dataset['train'].map(formatting_prompts_func, batched = True,)
# Out:
# Map:   0%|          | 0/1000000 [00:00<?, ? examples/s]

# %%
#print a smaple training example
train_dataset['text'][0]
# Out:
# "You are a great mathematician and you are tasked with finding if an answer to a given maths question is correct or not. Yout response should be 'True' if correct, otherwise 'False'. Below is Question and Answer.\n\n\n\n### Question:\nWhat is the radius of the circle inscribed in triangle $ABC$ if $AB = 22, AC=12,$ and $BC=14$? Express your answer in simplest radical form.\n\n### Answer:\n3.16227766016838\n\n### Explainaition\n\n### Output:\nTrue<|end_of_text|>"

# %%
# 划分训练集和验证集
dataset_split = dataset['train'].train_test_split(test_size=0.1)
train_dataset = dataset_split['train']
eval_dataset = dataset_split['test']

# 重新生成 'text' 字段
train_dataset = train_dataset.map(formatting_prompts_func, batched=True)
eval_dataset = eval_dataset.map(formatting_prompts_func, batched=True)

# 检查生成的字段是否正确
print("train text:", train_dataset.column_names)
print("validate text:", eval_dataset.column_names)
# Out:
# Map:   0%|          | 0/900000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100000 [00:00<?, ? examples/s]
# train text: ['question', 'is_correct', 'answer', 'solution', 'text']
# validate text: ['question', 'is_correct', 'answer', 'solution', 'text']

# %% [markdown]
# ## SFT

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

training_args = TrainingArguments(
    per_device_train_batch_size=2,
    gradient_accumulation_steps=8,  # 增加梯度累积步数，提升等效批次
    warmup_steps=50,                # 增加 warmup 步数，适应更长的训练
    max_steps=500,                  # 增加总训练步数
    learning_rate=2e-4,
    fp16=not is_bfloat16_supported(),
    bf16=is_bfloat16_supported(),
    logging_steps=10,
    eval_steps=50,
    optim="adamw_8bit",
    weight_decay=0.01,
    lr_scheduler_type="linear",
    seed=3407,
    output_dir="outputs",
    report_to="none"
)

trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,  # 添加验证集，监控模型效果
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    dataset_num_proc=4,
    packing=False,
    args=training_args
)
# Out:
# Map (num_proc=4):   0%|          | 0/900000 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/100000 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 900,000 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 8
# \        /    Total batch size = 16 | Total steps = 500
#  "-____-"     Number of trainable parameters = 41,943,040
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 29:39, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.332900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.769800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.950100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.828800</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.769100</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.737500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.750100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.718000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.749900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.722000</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.740600</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.713800</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.686000</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.736200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.761400</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.698100</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.692100</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.729200</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.710100</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.691200</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.671800</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.701400</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.742900</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.698600</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.743400</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.714200</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.708000</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.670700</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.720500</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.667600</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.665700</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.682000</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.674100</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.664000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.703800</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.679200</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.690400</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.660700</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.649700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.708800</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.618900</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.675000</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.630700</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.700300</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.648600</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.626200</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.640800</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.678400</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.639700</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.652300</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
import random
import torch
from sklearn.metrics import accuracy_score
import pandas as pd
from unsloth import FastLanguageModel

# 启用快速推理模式
FastLanguageModel.for_inference(model)

# 1. 随机抽取1,000条样本
sample_size = 1000
eval_sample = eval_dataset.select(random.sample(range(len(eval_dataset)), sample_size))

# 2. 设置批量大小
batch_size = 32
predictions = []
true_labels = eval_sample["is_correct"]

# 3. 批量处理抽取的样本
for i in range(0, len(eval_sample), batch_size):
    batch = eval_sample.select(range(i, min(i + batch_size, len(eval_sample))))
    input_prompts = [
        f"### Question:\n{item['question']}\n\n### Answer:\n{item['answer']}\n\n### Output:\n"
        for item in batch
    ]

    # 使用 tokenizer 处理批次输入
    inputs = tokenizer(input_prompts, return_tensors="pt", padding=True, truncation=True, max_length=512)

    # 将输入数据移动到 GPU（如果有）
    inputs = {k: v.to("cuda") for k, v in inputs.items()} if torch.cuda.is_available() else inputs

    # 批量生成预测结果
    outputs = model.generate(inputs["input_ids"], attention_mask=inputs["attention_mask"], max_new_tokens=64)
    responses = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    # 将每个响应转化为 True 或 False
    batch_predictions = [response.strip() == "True" for response in responses]
    predictions.extend(batch_predictions)

# 4. 计算抽样验证集的准确率
accuracy = accuracy_score(true_labels, predictions)
print(f"抽样验证集准确率: {accuracy:.2f}")
# Out:
# 抽样验证集准确率: 0.60

# %%
from tqdm import tqdm
import pandas as pd
from unsloth import FastLanguageModel

# 确保已加载测试集
test_dataset = dataset['test']

# 启用快速推理模式
FastLanguageModel.for_inference(model)

# 初始化预测结果列表
test_predictions = []

# 设置批量大小
batch_size = 32

# 使用 tqdm 包装循环以显示进度条
for i in tqdm(range(0, len(test_dataset), batch_size), desc="Processing test dataset"):
    # 分批获取测试数据
    batch = test_dataset.select(range(i, min(i + batch_size, len(test_dataset))))
    input_prompts = [
        f"### Question:\n{item['question']}\n\n### Answer:\n{item['answer']}\n\n### Output:\n"
        for item in batch
    ]

    # 使用 tokenizer 对批次进行处理
    inputs = tokenizer(input_prompts, return_tensors="pt", padding=True, truncation=True, max_length=512)

    # 将输入数据移动到 GPU（如果可用）
    inputs = {k: v.to("cuda") for k, v in inputs.items()} if torch.cuda.is_available() else inputs

    # 批量生成预测结果
    outputs = model.generate(inputs["input_ids"], attention_mask=inputs["attention_mask"], max_new_tokens=64)
    responses = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    # 解析每个响应并存储到列表
    for j, response in enumerate(responses):
        is_correct = response.strip() == "True"  # 检查预测结果是否为“True”
        test_predictions.append({"ID": i + j, "is_correct": is_correct})

# 将预测结果保存为符合竞赛格式的CSV文件
submission_df = pd.DataFrame(test_predictions)
submission_df.to_csv("submission_competition.csv", index=False)

print("测试集预测结果已生成并保存为 submission_competition.csv 文件。")
# Out:
# Processing test dataset: 100%|██████████| 313/313 [29:27<00:00,  5.65s/it]
# 测试集预测结果已生成并保存为 submission_competition.csv 文件。

# %%
from google.colab import files
files.download("submission_competition.csv")

# %% [markdown]
# ## inference

# %%
from tqdm import tqdm
from unsloth import FastLanguageModel

# 启用快速推理模式
FastLanguageModel.for_inference(model)

# 遍历前20个样本并进行推理
num_samples = 100
results = []

for i in tqdm(range(num_samples), desc="Running inference for 20 samples"):
    sample_ques = test_dataset['question'][i]
    sample_ans = test_dataset['answer'][i]

    # 构造输入提示
    input_prompt = prompt.format(sample_ques, sample_ans, "")

    # 编码输入提示
    inputs = tokenizer([input_prompt], return_tensors="pt").to("cuda")
    input_shape = inputs['input_ids'].shape
    input_token_len = input_shape[1]

    # 生成响应，并限制生成长度
    outputs = model.generate(**inputs, max_new_tokens=5, use_cache=True, eos_token_id=tokenizer.eos_token_id)
    response = tokenizer.decode(outputs[0][input_token_len:], skip_special_tokens=True).strip()

    # 判断生成的响应是否为“True”或“False”
    if 'true' in response.lower():
        is_correct = 'True'
    elif 'false' in response.lower():
        is_correct = 'False'
    else:
        is_correct = "missing"  # 若生成的结果无法判断

    # 仅保存ID和判断结果
    results.append({'ID': i, 'is_correct': is_correct})

# 打印出所有结果
for result in results:
    print(result)
# Out:
# Running inference for 20 samples: 100%|██████████| 100/100 [00:22<00:00,  4.54it/s]
# {'ID': 0, 'is_correct': 'True'}
# {'ID': 1, 'is_correct': 'False'}
# {'ID': 2, 'is_correct': 'True'}
# {'ID': 3, 'is_correct': 'True'}
# {'ID': 4, 'is_correct': 'False'}
# {'ID': 5, 'is_correct': 'False'}
# {'ID': 6, 'is_correct': 'False'}
# {'ID': 7, 'is_correct': 'False'}
# {'ID': 8, 'is_correct': 'False'}
# {'ID': 9, 'is_correct': 'False'}
# {'ID': 10, 'is_correct': 'False'}
# {'ID': 11, 'is_correct': 'False'}
# {'ID': 12, 'is_correct': 'False'}
# {'ID': 13, 'is_correct': 'False'}
# {'ID': 14, 'is_correct': 'True'}
# {'ID': 15, 'is_correct': 'False'}
# {'ID': 16, 'is_correct': 'False'}
# {'ID': 17, 'is_correct': 'False'}
# {'ID': 18, 'is_correct': 'False'}
# {'ID': 19, 'is_correct': 'False'}
# {'ID': 20, 'is_correct': 'False'}
# {'ID': 21, 'is_correct': 'True'}
# {'ID': 22, 'is_correct': 'False'}
# {'ID': 23, 'is_correct': 'True'}
# {'ID': 24, 'is_correct': 'True'}
# {'ID': 25, 'is_correct': 'True'}
# {'ID': 26, 'is_correct': 'False'}
# {'ID': 27, 'is_correct': 'False'}
# {'ID': 28, 'is_correct': 'False'}
# {'ID': 29, 'is_correct': 'True'}
# {'ID': 30, 'is_correct': 'True'}
# {'ID': 31, 'is_correct': 'False'}
# {'ID': 32, 'is_correct': 'False'}
# {'ID': 33, 'is_correct': 'False'}
# {'ID': 34, 'is_correct': 'False'}
# {'ID': 35, 'is_correct': 'True'}
# {'ID': 36, 'is_correct': 'False'}
# {'ID': 37, 'is_correct': 'False'}
# {'ID': 38, 'is_correct': 'True'}
# {'ID': 39, 'is_correct': 'False'}
# {'ID': 40, 'is_correct': 'True'}
# {'ID': 41, 'is_correct': 'False'}
# {'ID': 42, 'is_correct': 'False'}
# {'ID': 43, 'is_correct': 'True'}
# {'ID': 44, 'is_correct': 'False'}
# {'ID': 45, 'is_correct': 'False'}
# {'ID': 46, 'is_correct': 'False'}
# {'ID': 47, 'is_correct': 'True'}
# {'ID': 48, 'is_correct': 'False'}
# {'ID': 49, 'is_correct': 'True'}
# {'ID': 50, 'is_correct': 'False'}
# {'ID': 51, 'is_correct': 'True'}
# {'ID': 52, 'is_correct': 'False'}
# {'ID': 53, 'is_correct': 'False'}
# {'ID': 54, 'is_correct': 'False'}
# {'ID': 55, 'is_correct': 'False'}
# {'ID': 56, 'is_correct': 'False'}
# {'ID': 57, 'is_correct': 'True'}
# {'ID': 58, 'is_correct': 'False'}
# {'ID': 59, 'is_correct': 'False'}
# {'ID': 60, 'is_correct': 'False'}
# {'ID': 61, 'is_correct': 'True'}
# {'ID': 62, 'is_correct': 'True'}
# {'ID': 63, 'is_correct': 'False'}
# {'ID': 64, 'is_correct': 'True'}
# {'ID': 65, 'is_correct': 'True'}
# {'ID': 66, 'is_correct': 'False'}
# {'ID': 67, 'is_correct': 'False'}
# {'ID': 68, 'is_correct': 'True'}
# {'ID': 69, 'is_correct': 'False'}
# {'ID': 70, 'is_correct': 'False'}
# {'ID': 71, 'is_correct': 'True'}
# {'ID': 72, 'is_correct': 'False'}
# {'ID': 73, 'is_correct': 'True'}
# {'ID': 74, 'is_correct': 'False'}
# {'ID': 75, 'is_correct': 'True'}
# {'ID': 76, 'is_correct': 'False'}
# {'ID': 77, 'is_correct': 'False'}
# {'ID': 78, 'is_correct': 'False'}
# {'ID': 79, 'is_correct': 'True'}
# {'ID': 80, 'is_correct': 'False'}
# {'ID': 81, 'is_correct': 'False'}
# {'ID': 82, 'is_correct': 'False'}
# {'ID': 83, 'is_correct': 'False'}
# {'ID': 84, 'is_correct': 'True'}
# {'ID': 85, 'is_correct': 'False'}
# {'ID': 86, 'is_correct': 'True'}
# {'ID': 87, 'is_correct': 'False'}
# {'ID': 88, 'is_correct': 'False'}
# {'ID': 89, 'is_correct': 'False'}
# {'ID': 90, 'is_correct': 'False'}
# {'ID': 91, 'is_correct': 'False'}
# {'ID': 92, 'is_correct': 'False'}
# {'ID': 93, 'is_correct': 'False'}
# {'ID': 94, 'is_correct': 'False'}
# {'ID': 95, 'is_correct': 'True'}
# {'ID': 96, 'is_correct': 'False'}
# {'ID': 97, 'is_correct': 'False'}
# {'ID': 98, 'is_correct': 'False'}
# {'ID': 99, 'is_correct': 'True'}

# %%
from tqdm import tqdm
from unsloth import FastLanguageModel

# 启用快速推理模式
FastLanguageModel.for_inference(model)

# 设置批量大小和样本总数
batch_size = 32
num_samples = len(test_dataset) # 总共处理的样本数量

results = []

# 逐批处理样本
for start_idx in tqdm(range(0, num_samples, batch_size), desc="Running inference in batches"):
    # 获取当前批次的样本
    end_idx = min(start_idx + batch_size, num_samples)
    batch_samples = test_dataset['question'][start_idx:end_idx]
    batch_answers = test_dataset['answer'][start_idx:end_idx]

    # 构造输入提示
    input_prompts = [prompt.format(q, a, "") for q, a in zip(batch_samples, batch_answers)]

    # 编码输入提示
    inputs = tokenizer(input_prompts, return_tensors="pt", padding=True, truncation=True).to("cuda")
    input_shape = inputs['input_ids'].shape[1]

    # 执行批量生成
    outputs = model.generate(**inputs, max_new_tokens=5, use_cache=True, eos_token_id=tokenizer.eos_token_id)

    # 解码并解析批量生成的响应
    responses = tokenizer.batch_decode(outputs[:, input_shape:], skip_special_tokens=True)

    for i, response in enumerate(responses):
        # 判断生成的响应是否包含“True”或“False”
        if 'true' in response.lower():
            is_correct = 'True'
        elif 'false' in response.lower():
            is_correct = 'False'
        else:
            is_correct = "无法判断"  # 若生成的结果无法判断

        # 保存结果
        results.append({'ID': start_idx + i, 'is_correct': is_correct})

# 打印出所有结果
for result in results:
    print(result)
# Out:
# Running inference in batches: 100%|██████████| 313/313 [05:24<00:00,  1.04s/it]
# Streaming output truncated to the last 5000 lines.
# {'ID': 5000, 'is_correct': 'True'}
# {'ID': 5001, 'is_correct': 'True'}
# {'ID': 5002, 'is_correct': 'True'}
# {'ID': 5003, 'is_correct': 'False'}
# {'ID': 5004, 'is_correct': 'True'}
# {'ID': 5005, 'is_correct': 'True'}
# {'ID': 5006, 'is_correct': 'False'}
# {'ID': 5007, 'is_correct': 'False'}
# {'ID': 5008, 'is_correct': 'False'}
# {'ID': 5009, 'is_correct': 'False'}
# {'ID': 5010, 'is_correct': 'False'}
# {'ID': 5011, 'is_correct': 'True'}
# {'ID': 5012, 'is_correct': 'False'}
# {'ID': 5013, 'is_correct': 'False'}
# {'ID': 5014, 'is_correct': 'False'}
# {'ID': 5015, 'is_correct': 'False'}
# {'ID': 5016, 'is_correct': 'True'}
# {'ID': 5017, 'is_correct': 'False'}
# {'ID': 5018, 'is_correct': 'False'}
# {'ID': 5019, 'is_correct': 'True'}
# {'ID': 5020, 'is_correct': 'True'}
# {'ID': 5021, 'is_correct': 'True'}
# {'ID': 5022, 'is_correct': 'True'}
# {'ID': 5023, 'is_correct': 'False'}
# {'ID': 5024, 'is_correct': 'True'}
# {'ID': 5025, 'is_correct': 'True'}
# {'ID': 5026, 'is_correct': 'True'}
# {'ID': 5027, 'is_correct': 'True'}
# {'ID': 5028, 'is_correct': 'False'}
# {'ID': 5029, 'is_correct': 'False'}
# {'ID': 5030, 'is_correct': 'True'}
# {'ID': 5031, 'is_correct': 'True'}
# {'ID': 5032, 'is_correct': 'False'}
# {'ID': 5033, 'is_correct': 'False'}
# {'ID': 5034, 'is_correct': 'False'}
# {'ID': 5035, 'is_correct': 'True'}
# {'ID': 5036, 'is_correct': 'False'}
# {'ID': 5037, 'is_correct': 'False'}
# {'ID': 5038, 'is_correct': 'False'}
# {'ID': 5039, 'is_correct': 'False'}
# {'ID': 5040, 'is_correct': 'False'}
# {'ID': 5041, 'is_correct': 'False'}
# {'ID': 5042, 'is_correct': 'False'}
# {'ID': 5043, 'is_correct': 'False'}
# {'ID': 5044, 'is_correct': 'True'}
# {'ID': 5045, 'is_correct': 'False'}
# {'ID': 5046, 'is_correct': 'True'}
# {'ID': 5047, 'is_correct': 'True'}
# {'ID': 5048, 'is_correct': 'False'}
# {'ID': 5049, 'is_correct': 'False'}
# {'ID': 5050, 'is_correct': 'False'}
# {'ID': 5051, 'is_correct': 'False'}
# {'ID': 5052, 'is_correct': 'True'}
# {'ID': 5053, 'is_correct': 'True'}
# {'ID': 5054, 'is_correct': 'False'}
# {'ID': 5055, 'is_correct': 'False'}
# {'ID': 5056, 'is_correct': 'False'}
# {'ID': 5057, 'is_correct': 'True'}
# {'ID': 5058, 'is_correct': 'False'}
# {'ID': 5059, 'is_correct': 'False'}
# {'ID': 5060, 'is_correct': 'True'}
# {'ID': 5061, 'is_correct': 'False'}
# {'ID': 5062, 'is_correct': 'False'}
# {'ID': 5063, 'is_correct': 'False'}
# {'ID': 5064, 'is_correct': 'True'}
# {'ID': 5065, 'is_correct': 'False'}
# {'ID': 5066, 'is_correct': 'True'}
# {'ID': 5067, 'is_correct': 'False'}
# {'ID': 5068, 'is_correct': 'False'}
# {'ID': 5069, 'is_correct': 'False'}
# {'ID': 5070, 'is_correct': 'False'}
# {'ID': 5071, 'is_correct': 'True'}
# {'ID': 5072, 'is_correct': 'True'}
# {'ID': 5073, 'is_correct': 'False'}
# {'ID': 5074, 'is_correct': 'True'}
# {'ID': 5075, 'is_correct': 'False'}
# {'ID': 5076, 'is_correct': 'False'}
# {'ID': 5077, 'is_correct': 'False'}
# {'ID': 5078, 'is_correct': 'False'}
# {'ID': 5079, 'is_correct': 'False'}
# {'ID': 5080, 'is_correct': 'False'}
# {'ID': 5081, 'is_correct': 'True'}
# {'ID': 5082, 'is_correct': 'False'}
# {'ID': 5083, 'is_correct': 'False'}
# {'ID': 5084, 'is_correct': 'False'}
# {'ID': 5085, 'is_correct': 'True'}
# {'ID': 5086, 'is_correct': 'True'}
# {'ID': 5087, 'is_correct': 'True'}
# {'ID': 5088, 'is_correct': 'True'}
# {'ID': 5089, 'is_correct': 'False'}
# {'ID': 5090, 'is_correct': 'False'}
# {'ID': 5091, 'is_correct': 'False'}
# {'ID': 5092, 'is_correct': 'False'}
# {'ID': 5093, 'is_correct': 'False'}
# {'ID': 5094, 'is_correct': 'True'}
# {'ID': 5095, 'is_correct': 'True'}
# {'ID': 5096, 'is_correct': 'True'}
# {'ID': 5097, 'is_correct': 'False'}
# {'ID': 5098, 'is_correct': 'True'}
# {'ID': 5099, 'is_correct': 'False'}
# {'ID': 5100, 'is_correct': 'False'}
# {'ID': 5101, 'is_correct': 'True'}
# {'ID': 5102, 'is_correct': 'True'}
# {'ID': 5103, 'is_correct': 'True'}
# {'ID': 5104, 'is_correct': 'False'}
# {'ID': 5105, 'is_correct': 'False'}
# {'ID': 5106, 'is_correct': 'False'}
# {'ID': 5107, 'is_correct': 'False'}
# {'ID': 5108, 'is_correct': 'False'}
# {'ID': 5109, 'is_correct': 'False'}
# {'ID': 5110, 'is_correct': 'False'}
# {'ID': 5111, 'is_correct': 'False'}
# {'ID': 5112, 'is_correct': 'False'}
# {'ID': 5113, 'is_correct': 'False'}
# {'ID': 5114, 'is_correct': 'True'}
# {'ID': 5115, 'is_correct': 'True'}
# {'ID': 5116, 'is_correct': 'False'}
# {'ID': 5117, 'is_correct': 'False'}
# {'ID': 5118, 'is_correct': 'False'}
# {'ID': 5119, 'is_correct': 'False'}
# {'ID': 5120, 'is_correct': 'False'}
# {'ID': 5121, 'is_correct': 'True'}
# {'ID': 5122, 'is_correct': 'False'}
# {'ID': 5123, 'is_correct': 'False'}
# {'ID': 5124, 'is_correct': 'False'}
# {'ID': 5125, 'is_correct': 'False'}
# {'ID': 5126, 'is_correct': 'True'}
# {'ID': 5127, 'is_correct': 'True'}
# {'ID': 5128, 'is_correct': 'False'}
# {'ID': 5129, 'is_correct': 'False'}
# {'ID': 5130, 'is_correct': 'True'}
# {'ID': 5131, 'is_correct': 'True'}
# {'ID': 5132, 'is_correct': 'False'}
# {'ID': 5133, 'is_correct': 'False'}
# {'ID': 5134, 'is_correct': 'True'}
# {'ID': 5135, 'is_correct': 'True'}
# {'ID': 5136, 'is_correct': 'False'}
# {'ID': 5137, 'is_correct': 'True'}
# {'ID': 5138, 'is_correct': 'False'}
# {'ID': 5139, 'is_correct': 'False'}
# {'ID': 5140, 'is_correct': 'False'}
# {'ID': 5141, 'is_correct': 'False'}
# {'ID': 5142, 'is_correct': 'True'}
# {'ID': 5143, 'is_correct': 'False'}
# {'ID': 5144, 'is_correct': 'False'}
# {'ID': 5145, 'is_correct': 'True'}
# {'ID': 5146, 'is_correct': 'True'}
# {'ID': 5147, 'is_correct': 'False'}
# {'ID': 5148, 'is_correct': 'False'}
# {'ID': 5149, 'is_correct': 'False'}
# {'ID': 5150, 'is_correct': 'True'}
# {'ID': 5151, 'is_correct': 'False'}
# {'ID': 5152, 'is_correct': 'False'}
# {'ID': 5153, 'is_correct': 'True'}
# {'ID': 5154, 'is_correct': 'False'}
# {'ID': 5155, 'is_correct': 'False'}
# {'ID': 5156, 'is_correct': 'True'}
# {'ID': 5157, 'is_correct': 'True'}
# {'ID': 5158, 'is_correct': 'True'}
# {'ID': 5159, 'is_correct': 'False'}
# {'ID': 5160, 'is_correct': 'False'}
# {'ID': 5161, 'is_correct': 'False'}
# {'ID': 5162, 'is_correct': 'True'}
# {'ID': 5163, 'is_correct': 'False'}
# {'ID': 5164, 'is_correct': 'False'}
# {'ID': 5165, 'is_correct': 'False'}
# {'ID': 5166, 'is_correct': 'False'}
# {'ID': 5167, 'is_correct': 'False'}
# {'ID': 5168, 'is_correct': 'True'}
# {'ID': 5169, 'is_correct': 'False'}
# {'ID': 5170, 'is_correct': 'True'}
# {'ID': 5171, 'is_correct': 'True'}
# {'ID': 5172, 'is_correct': 'False'}
# {'ID': 5173, 'is_correct': 'False'}
# {'ID': 5174, 'is_correct': 'False'}
# {'ID': 5175, 'is_correct': 'False'}
# {'ID': 5176, 'is_correct': 'False'}
# {'ID': 5177, 'is_correct': 'False'}
# {'ID': 5178, 'is_correct': 'False'}
# {'ID': 5179, 'is_correct': 'False'}
# {'ID': 5180, 'is_correct': 'True'}
# {'ID': 5181, 'is_correct': 'True'}
# {'ID': 5182, 'is_correct': 'True'}
# {'ID': 5183, 'is_correct': 'True'}
# {'ID': 5184, 'is_correct': 'False'}
# {'ID': 5185, 'is_correct': 'False'}
# {'ID': 5186, 'is_correct': 'False'}
# {'ID': 5187, 'is_correct': 'False'}
# {'ID': 5188, 'is_correct': 'False'}
# {'ID': 5189, 'is_correct': 'False'}
# {'ID': 5190, 'is_correct': 'False'}
# {'ID': 5191, 'is_correct': 'False'}
# {'ID': 5192, 'is_correct': 'False'}
# {'ID': 5193, 'is_correct': 'False'}
# {'ID': 5194, 'is_correct': 'True'}
# {'ID': 5195, 'is_correct': 'False'}
# {'ID': 5196, 'is_correct': 'False'}
# {'ID': 5197, 'is_correct': 'True'}
# {'ID': 5198, 'is_correct': 'False'}
# {'ID': 5199, 'is_correct': 'False'}
# {'ID': 5200, 'is_correct': 'False'}
# {'ID': 5201, 'is_correct': 'True'}
# {'ID': 5202, 'is_correct': 'False'}
# {'ID': 5203, 'is_correct': 'True'}
# {'ID': 5204, 'is_correct': 'True'}
# {'ID': 5205, 'is_correct': 'True'}
# {'ID': 5206, 'is_correct': 'False'}
# {'ID': 5207, 'is_correct': 'False'}
# {'ID': 5208, 'is_correct': 'True'}
# {'ID': 5209, 'is_correct': 'True'}
# {'ID': 5210, 'is_correct': 'True'}
# {'ID': 5211, 'is_correct': 'False'}
# {'ID': 5212, 'is_correct': 'False'}
# {'ID': 5213, 'is_correct': 'True'}
# {'ID': 5214, 'is_correct': 'False'}
# {'ID': 5215, 'is_correct': 'False'}
# {'ID': 5216, 'is_correct': 'True'}
# {'ID': 5217, 'is_correct': 'False'}
# {'ID': 5218, 'is_correct': 'False'}
# {'ID': 5219, 'is_correct': 'False'}
# {'ID': 5220, 'is_correct': 'False'}
# {'ID': 5221, 'is_correct': 'True'}
# {'ID': 5222, 'is_correct': 'False'}
# {'ID': 5223, 'is_correct': 'False'}
# {'ID': 5224, 'is_correct': 'False'}
# {'ID': 5225, 'is_correct': 'True'}
# {'ID': 5226, 'is_correct': 'False'}
# {'ID': 5227, 'is_correct': 'False'}
# {'ID': 5228, 'is_correct': 'True'}
# {'ID': 5229, 'is_correct': 'False'}
# {'ID': 5230, 'is_correct': 'False'}
# {'ID': 5231, 'is_correct': 'False'}
# {'ID': 5232, 'is_correct': 'False'}
# {'ID': 5233, 'is_correct': 'False'}
# {'ID': 5234, 'is_correct': 'False'}
# {'ID': 5235, 'is_correct': 'False'}
# {'ID': 5236, 'is_correct': 'False'}
# {'ID': 5237, 'is_correct': 'True'}
# {'ID': 5238, 'is_correct': 'False'}
# {'ID': 5239, 'is_correct': 'False'}
# {'ID': 5240, 'is_correct': 'True'}
# {'ID': 5241, 'is_correct': 'False'}
# {'ID': 5242, 'is_correct': 'True'}
# {'ID': 5243, 'is_correct': 'False'}
# {'ID': 5244, 'is_correct': 'True'}
# {'ID': 5245, 'is_correct': 'False'}
# {'ID': 5246, 'is_correct': 'True'}
# {'ID': 5247, 'is_correct': 'False'}
# {'ID': 5248, 'is_correct': 'True'}
# {'ID': 5249, 'is_correct': 'False'}
# {'ID': 5250, 'is_correct': 'False'}
# {'ID': 5251, 'is_correct': 'True'}
# {'ID': 5252, 'is_correct': 'False'}
# {'ID': 5253, 'is_correct': 'True'}
# {'ID': 5254, 'is_correct': 'True'}
# {'ID': 5255, 'is_correct': 'True'}
# {'ID': 5256, 'is_correct': 'True'}
# {'ID': 5257, 'is_correct': 'False'}
# {'ID': 5258, 'is_correct': 'True'}
# {'ID': 5259, 'is_correct': 'False'}
# {'ID': 5260, 'is_correct': 'True'}
# {'ID': 5261, 'is_correct': 'True'}
# {'ID': 5262, 'is_correct': 'True'}
# {'ID': 5263, 'is_correct': 'False'}
# {'ID': 5264, 'is_correct': 'False'}
# {'ID': 5265, 'is_correct': 'True'}
# {'ID': 5266, 'is_correct': 'True'}
# {'ID': 5267, 'is_correct': 'False'}
# {'ID': 5268, 'is_correct': 'False'}
# {'ID': 5269, 'is_correct': 'False'}
# {'ID': 5270, 'is_correct': 'False'}
# {'ID': 5271, 'is_correct': 'True'}
# {'ID': 5272, 'is_correct': 'False'}
# {'ID': 5273, 'is_correct': 'False'}
# {'ID': 5274, 'is_correct': 'True'}
# {'ID': 5275, 'is_correct': 'False'}
# {'ID': 5276, 'is_correct': 'False'}
# {'ID': 5277, 'is_correct': 'False'}
# {'ID': 5278, 'is_correct': 'False'}
# {'ID': 5279, 'is_correct': 'True'}
# {'ID': 5280, 'is_correct': 'True'}
# {'ID': 5281, 'is_correct': 'True'}
# {'ID': 5282, 'is_correct': 'True'}
# {'ID': 5283, 'is_correct': 'True'}
# {'ID': 5284, 'is_correct': 'False'}
# {'ID': 5285, 'is_correct': 'False'}
# {'ID': 5286, 'is_correct': 'False'}
# {'ID': 5287, 'is_correct': 'True'}
# {'ID': 5288, 'is_correct': 'True'}
# {'ID': 5289, 'is_correct': 'False'}
# {'ID': 5290, 'is_correct': 'True'}
# {'ID': 5291, 'is_correct': 'False'}
# {'ID': 5292, 'is_correct': 'True'}
# {'ID': 5293, 'is_correct': 'False'}
# {'ID': 5294, 'is_correct': 'True'}
# {'ID': 5295, 'is_correct': 'True'}
# {'ID': 5296, 'is_correct': 'True'}
# {'ID': 5297, 'is_correct': 'False'}
# {'ID': 5298, 'is_correct': 'True'}
# {'ID': 5299, 'is_correct': 'False'}
# {'ID': 5300, 'is_correct': 'False'}
# {'ID': 5301, 'is_correct': 'True'}
# {'ID': 5302, 'is_correct': 'False'}
# {'ID': 5303, 'is_correct': 'False'}
# {'ID': 5304, 'is_correct': 'True'}
# {'ID': 5305, 'is_correct': 'True'}
# {'ID': 5306, 'is_correct': 'False'}
# {'ID': 5307, 'is_correct': 'False'}
# {'ID': 5308, 'is_correct': 'True'}
# {'ID': 5309, 'is_correct': 'False'}
# {'ID': 5310, 'is_correct': 'True'}
# {'ID': 5311, 'is_correct': 'True'}
# {'ID': 5312, 'is_correct': 'False'}
# {'ID': 5313, 'is_correct': 'False'}
# {'ID': 5314, 'is_correct': 'False'}
# {'ID': 5315, 'is_correct': 'False'}
# {'ID': 5316, 'is_correct': 'True'}
# {'ID': 5317, 'is_correct': 'True'}
# {'ID': 5318, 'is_correct': 'False'}
# {'ID': 5319, 'is_correct': 'False'}
# {'ID': 5320, 'is_correct': 'True'}
# {'ID': 5321, 'is_correct': 'False'}
# {'ID': 5322, 'is_correct': 'False'}
# {'ID': 5323, 'is_correct': 'False'}
# {'ID': 5324, 'is_correct': 'False'}
# {'ID': 5325, 'is_correct': 'False'}
# {'ID': 5326, 'is_correct': 'True'}
# {'ID': 5327, 'is_correct': 'False'}
# {'ID': 5328, 'is_correct': 'False'}
# {'ID': 5329, 'is_correct': 'True'}
# {'ID': 5330, 'is_correct': 'False'}
# {'ID': 5331, 'is_correct': 'True'}
# {'ID': 5332, 'is_correct': 'False'}
# {'ID': 5333, 'is_correct': 'True'}
# {'ID': 5334, 'is_correct': 'True'}
# {'ID': 5335, 'is_correct': 'True'}
# {'ID': 5336, 'is_correct': 'False'}
# {'ID': 5337, 'is_correct': 'True'}
# {'ID': 5338, 'is_correct': 'False'}
# {'ID': 5339, 'is_correct': 'True'}
# {'ID': 5340, 'is_correct': 'False'}
# {'ID': 5341, 'is_correct': 'False'}
# {'ID': 5342, 'is_correct': 'False'}
# {'ID': 5343, 'is_correct': 'True'}
# {'ID': 5344, 'is_correct': 'True'}
# {'ID': 5345, 'is_correct': 'False'}
# {'ID': 5346, 'is_correct': 'True'}
# {'ID': 5347, 'is_correct': 'True'}
# {'ID': 5348, 'is_correct': 'False'}
# {'ID': 5349, 'is_correct': 'True'}
# {'ID': 5350, 'is_correct': 'False'}
# {'ID': 5351, 'is_correct': 'True'}
# {'ID': 5352, 'is_correct': 'False'}
# {'ID': 5353, 'is_correct': 'False'}
# {'ID': 5354, 'is_correct': 'False'}
# {'ID': 5355, 'is_correct': 'False'}
# {'ID': 5356, 'is_correct': 'True'}
# {'ID': 5357, 'is_correct': 'True'}
# {'ID': 5358, 'is_correct': 'True'}
# {'ID': 5359, 'is_correct': 'True'}
# {'ID': 5360, 'is_correct': 'False'}
# {'ID': 5361, 'is_correct': 'True'}
# {'ID': 5362, 'is_correct': 'True'}
# {'ID': 5363, 'is_correct': 'False'}
# {'ID': 5364, 'is_correct': 'False'}
# {'ID': 5365, 'is_correct': 'False'}
# {'ID': 5366, 'is_correct': 'True'}
# {'ID': 5367, 'is_correct': 'False'}
# {'ID': 5368, 'is_correct': 'False'}
# {'ID': 5369, 'is_correct': 'True'}
# {'ID': 5370, 'is_correct': 'True'}
# {'ID': 5371, 'is_correct': 'False'}
# {'ID': 5372, 'is_correct': 'False'}
# {'ID': 5373, 'is_correct': 'True'}
# {'ID': 5374, 'is_correct': 'False'}
# {'ID': 5375, 'is_correct': 'False'}
# {'ID': 5376, 'is_correct': 'True'}
# {'ID': 5377, 'is_correct': 'False'}
# {'ID': 5378, 'is_correct': 'True'}
# {'ID': 5379, 'is_correct': 'False'}
# {'ID': 5380, 'is_correct': 'False'}
# {'ID': 5381, 'is_correct': 'True'}
# {'ID': 5382, 'is_correct': 'False'}
# {'ID': 5383, 'is_correct': 'False'}
# {'ID': 5384, 'is_correct': 'True'}
# {'ID': 5385, 'is_correct': 'True'}
# {'ID': 5386, 'is_correct': 'True'}
# {'ID': 5387, 'is_correct': 'True'}
# {'ID': 5388, 'is_correct': 'False'}
# {'ID': 5389, 'is_correct': 'False'}
# {'ID': 5390, 'is_correct': 'False'}
# {'ID': 5391, 'is_correct': 'False'}
# {'ID': 5392, 'is_correct': 'True'}
# {'ID': 5393, 'is_correct': 'False'}
# {'ID': 5394, 'is_correct': 'False'}
# {'ID': 5395, 'is_correct': 'False'}
# {'ID': 5396, 'is_correct': 'True'}
# {'ID': 5397, 'is_correct': 'False'}
# {'ID': 5398, 'is_correct': 'True'}
# {'ID': 5399, 'is_correct': 'False'}
# {'ID': 5400, 'is_correct': 'True'}
# {'ID': 5401, 'is_correct': 'True'}
# {'ID': 5402, 'is_correct': 'False'}
# {'ID': 5403, 'is_correct': 'False'}
# {'ID': 5404, 'is_correct': 'False'}
# {'ID': 5405, 'is_correct': 'False'}
# {'ID': 5406, 'is_correct': 'True'}
# {'ID': 5407, 'is_correct': 'False'}
# {'ID': 5408, 'is_correct': 'False'}
# {'ID': 5409, 'is_correct': 'False'}
# {'ID': 5410, 'is_correct': 'False'}
# {'ID': 5411, 'is_correct': 'True'}
# {'ID': 5412, 'is_correct': 'False'}
# {'ID': 5413, 'is_correct': 'False'}
# {'ID': 5414, 'is_correct': 'False'}
# {'ID': 5415, 'is_correct': 'True'}
# {'ID': 5416, 'is_correct': 'True'}
# {'ID': 5417, 'is_correct': 'True'}
# {'ID': 5418, 'is_correct': 'False'}
# {'ID': 5419, 'is_correct': 'True'}
# {'ID': 5420, 'is_correct': 'False'}
# {'ID': 5421, 'is_correct': 'False'}
# {'ID': 5422, 'is_correct': 'True'}
# {'ID': 5423, 'is_correct': 'False'}
# {'ID': 5424, 'is_correct': 'False'}
# {'ID': 5425, 'is_correct': 'False'}
# {'ID': 5426, 'is_correct': 'True'}
# {'ID': 5427, 'is_correct': 'False'}
# {'ID': 5428, 'is_correct': 'False'}
# {'ID': 5429, 'is_correct': 'False'}
# {'ID': 5430, 'is_correct': 'True'}
# {'ID': 5431, 'is_correct': 'False'}
# {'ID': 5432, 'is_correct': 'True'}
# {'ID': 5433, 'is_correct': 'True'}
# {'ID': 5434, 'is_correct': 'True'}
# {'ID': 5435, 'is_correct': 'True'}
# {'ID': 5436, 'is_correct': 'False'}
# {'ID': 5437, 'is_correct': 'False'}
# {'ID': 5438, 'is_correct': 'True'}
# {'ID': 5439, 'is_correct': 'True'}
# {'ID': 5440, 'is_correct': 'False'}
# {'ID': 5441, 'is_correct': 'True'}
# {'ID': 5442, 'is_correct': 'True'}
# {'ID': 5443, 'is_correct': 'False'}
# {'ID': 5444, 'is_correct': 'False'}
# {'ID': 5445, 'is_correct': 'False'}
# {'ID': 5446, 'is_correct': 'False'}
# {'ID': 5447, 'is_correct': 'False'}
# {'ID': 5448, 'is_correct': 'True'}
# {'ID': 5449, 'is_correct': 'False'}
# {'ID': 5450, 'is_correct': 'False'}
# {'ID': 5451, 'is_correct': 'False'}
# {'ID': 5452, 'is_correct': 'False'}
# {'ID': 5453, 'is_correct': 'False'}
# {'ID': 5454, 'is_correct': 'True'}
# {'ID': 5455, 'is_correct': 'False'}
# {'ID': 5456, 'is_correct': 'True'}
# {'ID': 5457, 'is_correct': 'True'}
# {'ID': 5458, 'is_correct': 'False'}
# {'ID': 5459, 'is_correct': 'True'}
# {'ID': 5460, 'is_correct': 'True'}
# {'ID': 5461, 'is_correct': 'False'}
# {'ID': 5462, 'is_correct': 'True'}
# {'ID': 5463, 'is_correct': 'True'}
# {'ID': 5464, 'is_correct': 'True'}
# {'ID': 5465, 'is_correct': 'True'}
# {'ID': 5466, 'is_correct': 'True'}
# {'ID': 5467, 'is_correct': 'False'}
# {'ID': 5468, 'is_correct': 'True'}
# {'ID': 5469, 'is_correct': 'False'}
# {'ID': 5470, 'is_correct': 'False'}
# {'ID': 5471, 'is_correct': 'False'}
# {'ID': 5472, 'is_correct': 'True'}
# {'ID': 5473, 'is_correct': 'True'}
# {'ID': 5474, 'is_correct': 'False'}
# {'ID': 5475, 'is_correct': 'False'}
# {'ID': 5476, 'is_correct': 'False'}
# {'ID': 5477, 'is_correct': 'False'}
# {'ID': 5478, 'is_correct': 'False'}
# {'ID': 5479, 'is_correct': 'True'}
# {'ID': 5480, 'is_correct': 'False'}
# {'ID': 5481, 'is_correct': 'False'}
# {'ID': 5482, 'is_correct': 'False'}
# {'ID': 5483, 'is_correct': 'True'}
# {'ID': 5484, 'is_correct': 'False'}
# {'ID': 5485, 'is_correct': 'False'}
# {'ID': 5486, 'is_correct': 'True'}
# {'ID': 5487, 'is_correct': 'False'}
# {'ID': 5488, 'is_correct': 'False'}
# {'ID': 5489, 'is_correct': 'True'}
# {'ID': 5490, 'is_correct': 'False'}
# {'ID': 5491, 'is_correct': 'False'}
# {'ID': 5492, 'is_correct': 'True'}
# {'ID': 5493, 'is_correct': 'True'}
# {'ID': 5494, 'is_correct': 'True'}
# {'ID': 5495, 'is_correct': 'True'}
# {'ID': 5496, 'is_correct': 'False'}
# {'ID': 5497, 'is_correct': 'False'}
# {'ID': 5498, 'is_correct': 'False'}
# {'ID': 5499, 'is_correct': 'True'}
# {'ID': 5500, 'is_correct': 'True'}
# {'ID': 5501, 'is_correct': 'False'}
# {'ID': 5502, 'is_correct': 'False'}
# {'ID': 5503, 'is_correct': 'True'}
# {'ID': 5504, 'is_correct': 'False'}
# {'ID': 5505, 'is_correct': 'False'}
# {'ID': 5506, 'is_correct': 'False'}
# {'ID': 5507, 'is_correct': 'True'}
# {'ID': 5508, 'is_correct': 'False'}
# {'ID': 5509, 'is_correct': 'True'}
# {'ID': 5510, 'is_correct': 'True'}
# {'ID': 5511, 'is_correct': 'False'}
# {'ID': 5512, 'is_correct': 'False'}
# {'ID': 5513, 'is_correct': 'True'}
# {'ID': 5514, 'is_correct': 'False'}
# {'ID': 5515, 'is_correct': 'False'}
# {'ID': 5516, 'is_correct': 'True'}
# {'ID': 5517, 'is_correct': 'True'}
# {'ID': 5518, 'is_correct': 'False'}
# {'ID': 5519, 'is_correct': 'False'}
# {'ID': 5520, 'is_correct': 'True'}
# {'ID': 5521, 'is_correct': 'True'}
# {'ID': 5522, 'is_correct': 'False'}
# {'ID': 5523, 'is_correct': 'False'}
# {'ID': 5524, 'is_correct': 'False'}
# {'ID': 5525, 'is_correct': 'False'}
# {'ID': 5526, 'is_correct': 'False'}
# {'ID': 5527, 'is_correct': 'False'}
# {'ID': 5528, 'is_correct': 'False'}
# {'ID': 5529, 'is_correct': 'False'}
# {'ID': 5530, 'is_correct': 'False'}
# {'ID': 5531, 'is_correct': 'True'}
# {'ID': 5532, 'is_correct': 'False'}
# {'ID': 5533, 'is_correct': 'False'}
# {'ID': 5534, 'is_correct': 'False'}
# {'ID': 5535, 'is_correct': 'True'}
# {'ID': 5536, 'is_correct': 'False'}
# {'ID': 5537, 'is_correct': 'False'}
# {'ID': 5538, 'is_correct': 'True'}
# {'ID': 5539, 'is_correct': 'False'}
# {'ID': 5540, 'is_correct': 'False'}
# {'ID': 5541, 'is_correct': 'False'}
# {'ID': 5542, 'is_correct': 'True'}
# {'ID': 5543, 'is_correct': 'False'}
# {'ID': 5544, 'is_correct': 'True'}
# {'ID': 5545, 'is_correct': 'False'}
# {'ID': 5546, 'is_correct': 'False'}
# {'ID': 5547, 'is_correct': 'False'}
# {'ID': 5548, 'is_correct': 'True'}
# {'ID': 5549, 'is_correct': 'False'}
# {'ID': 5550, 'is_correct': 'False'}
# {'ID': 5551, 'is_correct': 'False'}
# {'ID': 5552, 'is_correct': 'True'}
# {'ID': 5553, 'is_correct': 'False'}
# {'ID': 5554, 'is_correct': 'False'}
# {'ID': 5555, 'is_correct': 'False'}
# {'ID': 5556, 'is_correct': 'False'}
# {'ID': 5557, 'is_correct': 'False'}
# {'ID': 5558, 'is_correct': 'False'}
# {'ID': 5559, 'is_correct': 'False'}
# {'ID': 5560, 'is_correct': 'False'}
# {'ID': 5561, 'is_correct': 'False'}
# {'ID': 5562, 'is_correct': 'False'}
# {'ID': 5563, 'is_correct': 'False'}
# {'ID': 5564, 'is_correct': 'True'}
# {'ID': 5565, 'is_correct': 'True'}
# {'ID': 5566, 'is_correct': 'False'}
# {'ID': 5567, 'is_correct': 'False'}
# {'ID': 5568, 'is_correct': 'True'}
# {'ID': 5569, 'is_correct': 'False'}
# {'ID': 5570, 'is_correct': 'True'}
# {'ID': 5571, 'is_correct': 'False'}
# {'ID': 5572, 'is_correct': 'False'}
# {'ID': 5573, 'is_correct': 'False'}
# {'ID': 5574, 'is_correct': 'False'}
# {'ID': 5575, 'is_correct': 'False'}
# {'ID': 5576, 'is_correct': 'True'}
# {'ID': 5577, 'is_correct': 'False'}
# {'ID': 5578, 'is_correct': 'True'}
# {'ID': 5579, 'is_correct': 'True'}
# {'ID': 5580, 'is_correct': 'False'}
# {'ID': 5581, 'is_correct': 'False'}
# {'ID': 5582, 'is_correct': 'True'}
# {'ID': 5583, 'is_correct': 'False'}
# {'ID': 5584, 'is_correct': 'False'}
# {'ID': 5585, 'is_correct': 'False'}
# {'ID': 5586, 'is_correct': 'False'}
# {'ID': 5587, 'is_correct': 'False'}
# {'ID': 5588, 'is_correct': 'False'}
# {'ID': 5589, 'is_correct': 'False'}
# {'ID': 5590, 'is_correct': 'False'}
# {'ID': 5591, 'is_correct': 'False'}
# {'ID': 5592, 'is_correct': 'True'}
# {'ID': 5593, 'is_correct': 'False'}
# {'ID': 5594, 'is_correct': 'True'}
# {'ID': 5595, 'is_correct': 'False'}
# {'ID': 5596, 'is_correct': 'False'}
# {'ID': 5597, 'is_correct': 'False'}
# {'ID': 5598, 'is_correct': 'False'}
# {'ID': 5599, 'is_correct': 'False'}
# {'ID': 5600, 'is_correct': 'True'}
# {'ID': 5601, 'is_correct': 'False'}
# {'ID': 5602, 'is_correct': 'False'}
# {'ID': 5603, 'is_correct': 'False'}
# {'ID': 5604, 'is_correct': 'True'}
# {'ID': 5605, 'is_correct': 'True'}
# {'ID': 5606, 'is_correct': 'False'}
# {'ID': 5607, 'is_correct': 'False'}
# {'ID': 5608, 'is_correct': 'True'}
# {'ID': 5609, 'is_correct': 'False'}
# {'ID': 5610, 'is_correct': 'True'}
# {'ID': 5611, 'is_correct': 'False'}
# {'ID': 5612, 'is_correct': 'True'}
# {'ID': 5613, 'is_correct': 'False'}
# {'ID': 5614, 'is_correct': 'False'}
# {'ID': 5615, 'is_correct': 'False'}
# {'ID': 5616, 'is_correct': 'True'}
# {'ID': 5617, 'is_correct': 'False'}
# {'ID': 5618, 'is_correct': 'True'}
# {'ID': 5619, 'is_correct': 'False'}
# {'ID': 5620, 'is_correct': 'True'}
# {'ID': 5621, 'is_correct': 'False'}
# {'ID': 5622, 'is_correct': 'False'}
# {'ID': 5623, 'is_correct': 'False'}
# {'ID': 5624, 'is_correct': 'False'}
# {'ID': 5625, 'is_correct': 'False'}
# {'ID': 5626, 'is_correct': 'True'}
# {'ID': 5627, 'is_correct': 'True'}
# {'ID': 5628, 'is_correct': 'True'}
# {'ID': 5629, 'is_correct': 'False'}
# {'ID': 5630, 'is_correct': 'False'}
# {'ID': 5631, 'is_correct': 'True'}
# {'ID': 5632, 'is_correct': 'False'}
# {'ID': 5633, 'is_correct': 'False'}
# {'ID': 5634, 'is_correct': 'False'}
# {'ID': 5635, 'is_correct': 'False'}
# {'ID': 5636, 'is_correct': 'False'}
# {'ID': 5637, 'is_correct': 'True'}
# {'ID': 5638, 'is_correct': 'False'}
# {'ID': 5639, 'is_correct': 'True'}
# {'ID': 5640, 'is_correct': 'False'}
# {'ID': 5641, 'is_correct': 'False'}
# {'ID': 5642, 'is_correct': 'False'}
# {'ID': 5643, 'is_correct': 'True'}
# {'ID': 5644, 'is_correct': 'False'}
# {'ID': 5645, 'is_correct': 'False'}
# {'ID': 5646, 'is_correct': 'False'}
# {'ID': 5647, 'is_correct': 'False'}
# {'ID': 5648, 'is_correct': 'False'}
# {'ID': 5649, 'is_correct': 'False'}
# {'ID': 5650, 'is_correct': 'False'}
# {'ID': 5651, 'is_correct': 'False'}
# {'ID': 5652, 'is_correct': 'True'}
# {'ID': 5653, 'is_correct': 'False'}
# {'ID': 5654, 'is_correct': 'True'}
# {'ID': 5655, 'is_correct': 'False'}
# {'ID': 5656, 'is_correct': 'False'}
# {'ID': 5657, 'is_correct': 'False'}
# {'ID': 5658, 'is_correct': 'False'}
# {'ID': 5659, 'is_correct': 'False'}
# {'ID': 5660, 'is_correct': 'True'}
# {'ID': 5661, 'is_correct': 'False'}
# {'ID': 5662, 'is_correct': 'False'}
# {'ID': 5663, 'is_correct': 'False'}
# {'ID': 5664, 'is_correct': 'True'}
# {'ID': 5665, 'is_correct': 'False'}
# {'ID': 5666, 'is_correct': 'True'}
# {'ID': 5667, 'is_correct': 'False'}
# {'ID': 5668, 'is_correct': 'True'}
# {'ID': 5669, 'is_correct': 'True'}
# {'ID': 5670, 'is_correct': 'False'}
# {'ID': 5671, 'is_correct': 'False'}
# {'ID': 5672, 'is_correct': 'False'}
# {'ID': 5673, 'is_correct': 'False'}
# {'ID': 5674, 'is_correct': 'True'}
# {'ID': 5675, 'is_correct': 'False'}
# {'ID': 5676, 'is_correct': 'False'}
# {'ID': 5677, 'is_correct': 'True'}
# {'ID': 5678, 'is_correct': 'True'}
# {'ID': 5679, 'is_correct': 'False'}
# {'ID': 5680, 'is_correct': 'False'}
# {'ID': 5681, 'is_correct': 'True'}
# {'ID': 5682, 'is_correct': 'True'}
# {'ID': 5683, 'is_correct': 'False'}
# {'ID': 5684, 'is_correct': 'False'}
# {'ID': 5685, 'is_correct': 'True'}
# {'ID': 5686, 'is_correct': 'False'}
# {'ID': 5687, 'is_correct': 'True'}
# {'ID': 5688, 'is_correct': 'True'}
# {'ID': 5689, 'is_correct': 'True'}
# {'ID': 5690, 'is_correct': 'True'}
# {'ID': 5691, 'is_correct': 'False'}
# {'ID': 5692, 'is_correct': 'False'}
# {'ID': 5693, 'is_correct': 'False'}
# {'ID': 5694, 'is_correct': 'False'}
# {'ID': 5695, 'is_correct': 'False'}
# {'ID': 5696, 'is_correct': 'False'}
# {'ID': 5697, 'is_correct': 'True'}
# {'ID': 5698, 'is_correct': 'False'}
# {'ID': 5699, 'is_correct': 'True'}
# {'ID': 5700, 'is_correct': 'True'}
# {'ID': 5701, 'is_correct': 'True'}
# {'ID': 5702, 'is_correct': 'False'}
# {'ID': 5703, 'is_correct': 'False'}
# {'ID': 5704, 'is_correct': 'True'}
# {'ID': 5705, 'is_correct': 'True'}
# {'ID': 5706, 'is_correct': 'False'}
# {'ID': 5707, 'is_correct': 'False'}
# {'ID': 5708, 'is_correct': 'True'}
# {'ID': 5709, 'is_correct': 'False'}
# {'ID': 5710, 'is_correct': 'False'}
# {'ID': 5711, 'is_correct': 'False'}
# {'ID': 5712, 'is_correct': 'False'}
# {'ID': 5713, 'is_correct': 'False'}
# {'ID': 5714, 'is_correct': 'True'}
# {'ID': 5715, 'is_correct': 'True'}
# {'ID': 5716, 'is_correct': 'True'}
# {'ID': 5717, 'is_correct': 'False'}
# {'ID': 5718, 'is_correct': 'False'}
# {'ID': 5719, 'is_correct': 'False'}
# {'ID': 5720, 'is_correct': 'False'}
# {'ID': 5721, 'is_correct': 'True'}
# {'ID': 5722, 'is_correct': 'False'}
# {'ID': 5723, 'is_correct': 'False'}
# {'ID': 5724, 'is_correct': 'False'}
# {'ID': 5725, 'is_correct': 'False'}
# {'ID': 5726, 'is_correct': 'True'}
# {'ID': 5727, 'is_correct': 'False'}
# {'ID': 5728, 'is_correct': 'True'}
# {'ID': 5729, 'is_correct': 'False'}
# {'ID': 5730, 'is_correct': 'False'}
# {'ID': 5731, 'is_correct': 'False'}
# {'ID': 5732, 'is_correct': 'False'}
# {'ID': 5733, 'is_correct': 'False'}
# {'ID': 5734, 'is_correct': 'False'}
# {'ID': 5735, 'is_correct': 'True'}
# {'ID': 5736, 'is_correct': 'False'}
# {'ID': 5737, 'is_correct': 'False'}
# {'ID': 5738, 'is_correct': 'True'}
# {'ID': 5739, 'is_correct': 'True'}
# {'ID': 5740, 'is_correct': 'True'}
# {'ID': 5741, 'is_correct': 'False'}
# {'ID': 5742, 'is_correct': 'True'}
# {'ID': 5743, 'is_correct': 'False'}
# {'ID': 5744, 'is_correct': 'False'}
# {'ID': 5745, 'is_correct': 'False'}
# {'ID': 5746, 'is_correct': 'True'}
# {'ID': 5747, 'is_correct': 'False'}
# {'ID': 5748, 'is_correct': 'False'}
# {'ID': 5749, 'is_correct': 'True'}
# {'ID': 5750, 'is_correct': 'False'}
# {'ID': 5751, 'is_correct': 'True'}
# {'ID': 5752, 'is_correct': 'False'}
# {'ID': 5753, 'is_correct': 'False'}
# {'ID': 5754, 'is_correct': 'False'}
# {'ID': 5755, 'is_correct': 'False'}
# {'ID': 5756, 'is_correct': 'True'}
# {'ID': 5757, 'is_correct': 'True'}
# {'ID': 5758, 'is_correct': 'False'}
# {'ID': 5759, 'is_correct': 'False'}
# {'ID': 5760, 'is_correct': 'False'}
# {'ID': 5761, 'is_correct': 'False'}
# {'ID': 5762, 'is_correct': 'True'}
# {'ID': 5763, 'is_correct': 'True'}
# {'ID': 5764, 'is_correct': 'True'}
# {'ID': 5765, 'is_correct': 'False'}
# {'ID': 5766, 'is_correct': 'False'}
# {'ID': 5767, 'is_correct': 'True'}
# {'ID': 5768, 'is_correct': 'True'}
# {'ID': 5769, 'is_correct': 'False'}
# {'ID': 5770, 'is_correct': 'False'}
# {'ID': 5771, 'is_correct': 'False'}
# {'ID': 5772, 'is_correct': 'True'}
# {'ID': 5773, 'is_correct': 'False'}
# {'ID': 5774, 'is_correct': 'False'}
# {'ID': 5775, 'is_correct': 'False'}
# {'ID': 5776, 'is_correct': 'False'}
# {'ID': 5777, 'is_correct': 'False'}
# {'ID': 5778, 'is_correct': 'False'}
# {'ID': 5779, 'is_correct': 'False'}
# {'ID': 5780, 'is_correct': 'False'}
# {'ID': 5781, 'is_correct': 'True'}
# {'ID': 5782, 'is_correct': 'False'}
# {'ID': 5783, 'is_correct': 'False'}
# {'ID': 5784, 'is_correct': 'True'}
# {'ID': 5785, 'is_correct': 'True'}
# {'ID': 5786, 'is_correct': 'True'}
# {'ID': 5787, 'is_correct': 'False'}
# {'ID': 5788, 'is_correct': 'True'}
# {'ID': 5789, 'is_correct': 'False'}
# {'ID': 5790, 'is_correct': 'True'}
# {'ID': 5791, 'is_correct': 'False'}
# {'ID': 5792, 'is_correct': 'False'}
# {'ID': 5793, 'is_correct': 'True'}
# {'ID': 5794, 'is_correct': 'True'}
# {'ID': 5795, 'is_correct': 'False'}
# {'ID': 5796, 'is_correct': 'False'}
# {'ID': 5797, 'is_correct': 'False'}
# {'ID': 5798, 'is_correct': 'False'}
# {'ID': 5799, 'is_correct': 'True'}
# {'ID': 5800, 'is_correct': 'True'}
# {'ID': 5801, 'is_correct': 'False'}
# {'ID': 5802, 'is_correct': 'False'}
# {'ID': 5803, 'is_correct': 'False'}
# {'ID': 5804, 'is_correct': 'True'}
# {'ID': 5805, 'is_correct': 'False'}
# {'ID': 5806, 'is_correct': 'True'}
# {'ID': 5807, 'is_correct': 'True'}
# {'ID': 5808, 'is_correct': 'True'}
# {'ID': 5809, 'is_correct': 'False'}
# {'ID': 5810, 'is_correct': 'False'}
# {'ID': 5811, 'is_correct': 'False'}
# {'ID': 5812, 'is_correct': 'True'}
# {'ID': 5813, 'is_correct': 'False'}
# {'ID': 5814, 'is_correct': 'False'}
# {'ID': 5815, 'is_correct': 'False'}
# {'ID': 5816, 'is_correct': 'True'}
# {'ID': 5817, 'is_correct': 'False'}
# {'ID': 5818, 'is_correct': 'False'}
# {'ID': 5819, 'is_correct': 'False'}
# {'ID': 5820, 'is_correct': 'True'}
# {'ID': 5821, 'is_correct': 'False'}
# {'ID': 5822, 'is_correct': 'True'}
# {'ID': 5823, 'is_correct': 'False'}
# {'ID': 5824, 'is_correct': 'False'}
# {'ID': 5825, 'is_correct': 'False'}
# {'ID': 5826, 'is_correct': 'True'}
# {'ID': 5827, 'is_correct': 'False'}
# {'ID': 5828, 'is_correct': 'False'}
# {'ID': 5829, 'is_correct': 'False'}
# {'ID': 5830, 'is_correct': 'True'}
# {'ID': 5831, 'is_correct': 'True'}
# {'ID': 5832, 'is_correct': 'False'}
# {'ID': 5833, 'is_correct': 'True'}
# {'ID': 5834, 'is_correct': 'False'}
# {'ID': 5835, 'is_correct': 'True'}
# {'ID': 5836, 'is_correct': 'False'}
# {'ID': 5837, 'is_correct': 'False'}
# {'ID': 5838, 'is_correct': 'True'}
# {'ID': 5839, 'is_correct': 'True'}
# {'ID': 5840, 'is_correct': 'True'}
# {'ID': 5841, 'is_correct': 'False'}
# {'ID': 5842, 'is_correct': 'False'}
# {'ID': 5843, 'is_correct': 'False'}
# {'ID': 5844, 'is_correct': 'False'}
# {'ID': 5845, 'is_correct': 'False'}
# {'ID': 5846, 'is_correct': 'True'}
# {'ID': 5847, 'is_correct': 'False'}
# {'ID': 5848, 'is_correct': 'True'}
# {'ID': 5849, 'is_correct': 'True'}
# {'ID': 5850, 'is_correct': 'False'}
# {'ID': 5851, 'is_correct': 'False'}
# {'ID': 5852, 'is_correct': 'True'}
# {'ID': 5853, 'is_correct': 'True'}
# {'ID': 5854, 'is_correct': 'False'}
# {'ID': 5855, 'is_correct': 'True'}
# {'ID': 5856, 'is_correct': 'False'}
# {'ID': 5857, 'is_correct': 'False'}
# {'ID': 5858, 'is_correct': 'False'}
# {'ID': 5859, 'is_correct': 'False'}
# {'ID': 5860, 'is_correct': 'True'}
# {'ID': 5861, 'is_correct': 'False'}
# {'ID': 5862, 'is_correct': 'True'}
# {'ID': 5863, 'is_correct': 'False'}
# {'ID': 5864, 'is_correct': 'False'}
# {'ID': 5865, 'is_correct': 'False'}
# {'ID': 5866, 'is_correct': 'True'}
# {'ID': 5867, 'is_correct': 'False'}
# {'ID': 5868, 'is_correct': 'True'}
# {'ID': 5869, 'is_correct': 'False'}
# {'ID': 5870, 'is_correct': 'True'}
# {'ID': 5871, 'is_correct': 'False'}
# {'ID': 5872, 'is_correct': 'False'}
# {'ID': 5873, 'is_correct': 'True'}
# {'ID': 5874, 'is_correct': 'True'}
# {'ID': 5875, 'is_correct': 'False'}
# {'ID': 5876, 'is_correct': 'False'}
# {'ID': 5877, 'is_correct': 'True'}
# {'ID': 5878, 'is_correct': 'False'}
# {'ID': 5879, 'is_correct': 'True'}
# {'ID': 5880, 'is_correct': 'False'}
# {'ID': 5881, 'is_correct': 'False'}
# {'ID': 5882, 'is_correct': 'True'}
# {'ID': 5883, 'is_correct': 'False'}
# {'ID': 5884, 'is_correct': 'False'}
# {'ID': 5885, 'is_correct': 'True'}
# {'ID': 5886, 'is_correct': 'False'}
# {'ID': 5887, 'is_correct': 'False'}
# {'ID': 5888, 'is_correct': 'True'}
# {'ID': 5889, 'is_correct': 'True'}
# {'ID': 5890, 'is_correct': 'True'}
# {'ID': 5891, 'is_correct': 'False'}
# {'ID': 5892, 'is_correct': 'True'}
# {'ID': 5893, 'is_correct': 'False'}
# {'ID': 5894, 'is_correct': 'False'}
# {'ID': 5895, 'is_correct': 'False'}
# {'ID': 5896, 'is_correct': 'True'}
# {'ID': 5897, 'is_correct': 'False'}
# {'ID': 5898, 'is_correct': 'False'}
# {'ID': 5899, 'is_correct': 'True'}
# {'ID': 5900, 'is_correct': 'True'}
# {'ID': 5901, 'is_correct': 'True'}
# {'ID': 5902, 'is_correct': 'True'}
# {'ID': 5903, 'is_correct': 'True'}
# {'ID': 5904, 'is_correct': 'True'}
# {'ID': 5905, 'is_correct': 'True'}
# {'ID': 5906, 'is_correct': 'False'}
# {'ID': 5907, 'is_correct': 'True'}
# {'ID': 5908, 'is_correct': 'False'}
# {'ID': 5909, 'is_correct': 'False'}
# {'ID': 5910, 'is_correct': 'True'}
# {'ID': 5911, 'is_correct': 'False'}
# {'ID': 5912, 'is_correct': 'False'}
# {'ID': 5913, 'is_correct': 'False'}
# {'ID': 5914, 'is_correct': 'False'}
# {'ID': 5915, 'is_correct': 'True'}
# {'ID': 5916, 'is_correct': 'False'}
# {'ID': 5917, 'is_correct': 'False'}
# {'ID': 5918, 'is_correct': 'False'}
# {'ID': 5919, 'is_correct': 'False'}
# {'ID': 5920, 'is_correct': 'False'}
# {'ID': 5921, 'is_correct': 'False'}
# {'ID': 5922, 'is_correct': 'False'}
# {'ID': 5923, 'is_correct': 'False'}
# {'ID': 5924, 'is_correct': 'True'}
# {'ID': 5925, 'is_correct': 'False'}
# {'ID': 5926, 'is_correct': 'True'}
# {'ID': 5927, 'is_correct': 'True'}
# {'ID': 5928, 'is_correct': 'False'}
# {'ID': 5929, 'is_correct': 'False'}
# {'ID': 5930, 'is_correct': 'True'}
# {'ID': 5931, 'is_correct': 'False'}
# {'ID': 5932, 'is_correct': 'False'}
# {'ID': 5933, 'is_correct': 'False'}
# {'ID': 5934, 'is_correct': 'False'}
# {'ID': 5935, 'is_correct': 'True'}
# {'ID': 5936, 'is_correct': 'True'}
# {'ID': 5937, 'is_correct': 'False'}
# {'ID': 5938, 'is_correct': 'False'}
# {'ID': 5939, 'is_correct': 'False'}
# {'ID': 5940, 'is_correct': 'False'}
# {'ID': 5941, 'is_correct': 'False'}
# {'ID': 5942, 'is_correct': 'False'}
# {'ID': 5943, 'is_correct': 'False'}
# {'ID': 5944, 'is_correct': 'False'}
# {'ID': 5945, 'is_correct': 'False'}
# {'ID': 5946, 'is_correct': 'False'}
# {'ID': 5947, 'is_correct': 'False'}
# {'ID': 5948, 'is_correct': 'False'}
# {'ID': 5949, 'is_correct': 'True'}
# {'ID': 5950, 'is_correct': 'True'}
# {'ID': 5951, 'is_correct': 'False'}
# {'ID': 5952, 'is_correct': 'True'}
# {'ID': 5953, 'is_correct': 'True'}
# {'ID': 5954, 'is_correct': 'False'}
# {'ID': 5955, 'is_correct': 'False'}
# {'ID': 5956, 'is_correct': 'False'}
# {'ID': 5957, 'is_correct': 'True'}
# {'ID': 5958, 'is_correct': 'True'}
# {'ID': 5959, 'is_correct': 'False'}
# {'ID': 5960, 'is_correct': 'False'}
# {'ID': 5961, 'is_correct': 'True'}
# {'ID': 5962, 'is_correct': 'True'}
# {'ID': 5963, 'is_correct': 'True'}
# {'ID': 5964, 'is_correct': 'True'}
# {'ID': 5965, 'is_correct': 'False'}
# {'ID': 5966, 'is_correct': 'True'}
# {'ID': 5967, 'is_correct': 'True'}
# {'ID': 5968, 'is_correct': 'True'}
# {'ID': 5969, 'is_correct': 'False'}
# {'ID': 5970, 'is_correct': 'True'}
# {'ID': 5971, 'is_correct': 'False'}
# {'ID': 5972, 'is_correct': 'False'}
# {'ID': 5973, 'is_correct': 'False'}
# {'ID': 5974, 'is_correct': 'False'}
# {'ID': 5975, 'is_correct': 'True'}
# {'ID': 5976, 'is_correct': 'False'}
# {'ID': 5977, 'is_correct': 'False'}
# {'ID': 5978, 'is_correct': 'True'}
# {'ID': 5979, 'is_correct': 'False'}
# {'ID': 5980, 'is_correct': 'False'}
# {'ID': 5981, 'is_correct': 'True'}
# {'ID': 5982, 'is_correct': 'True'}
# {'ID': 5983, 'is_correct': 'False'}
# {'ID': 5984, 'is_correct': 'False'}
# {'ID': 5985, 'is_correct': 'False'}
# {'ID': 5986, 'is_correct': 'True'}
# {'ID': 5987, 'is_correct': 'False'}
# {'ID': 5988, 'is_correct': 'False'}
# {'ID': 5989, 'is_correct': 'True'}
# {'ID': 5990, 'is_correct': 'False'}
# {'ID': 5991, 'is_correct': 'False'}
# {'ID': 5992, 'is_correct': 'True'}
# {'ID': 5993, 'is_correct': 'False'}
# {'ID': 5994, 'is_correct': 'False'}
# {'ID': 5995, 'is_correct': 'False'}
# {'ID': 5996, 'is_correct': 'False'}
# {'ID': 5997, 'is_correct': 'False'}
# {'ID': 5998, 'is_correct': 'False'}
# {'ID': 5999, 'is_correct': 'True'}
# {'ID': 6000, 'is_correct': 'True'}
# {'ID': 6001, 'is_correct': 'False'}
# {'ID': 6002, 'is_correct': 'False'}
# {'ID': 6003, 'is_correct': 'False'}
# {'ID': 6004, 'is_correct': 'True'}
# {'ID': 6005, 'is_correct': 'False'}
# {'ID': 6006, 'is_correct': 'True'}
# {'ID': 6007, 'is_correct': 'True'}
# {'ID': 6008, 'is_correct': 'True'}
# {'ID': 6009, 'is_correct': 'False'}
# {'ID': 6010, 'is_correct': 'False'}
# {'ID': 6011, 'is_correct': 'False'}
# {'ID': 6012, 'is_correct': 'False'}
# {'ID': 6013, 'is_correct': 'False'}
# {'ID': 6014, 'is_correct': 'False'}
# {'ID': 6015, 'is_correct': 'False'}
# {'ID': 6016, 'is_correct': 'False'}
# {'ID': 6017, 'is_correct': 'False'}
# {'ID': 6018, 'is_correct': 'True'}
# {'ID': 6019, 'is_correct': 'False'}
# {'ID': 6020, 'is_correct': 'True'}
# {'ID': 6021, 'is_correct': 'False'}
# {'ID': 6022, 'is_correct': 'False'}
# {'ID': 6023, 'is_correct': 'False'}
# {'ID': 6024, 'is_correct': 'True'}
# {'ID': 6025, 'is_correct': 'True'}
# {'ID': 6026, 'is_correct': 'False'}
# {'ID': 6027, 'is_correct': 'True'}
# {'ID': 6028, 'is_correct': 'False'}
# {'ID': 6029, 'is_correct': 'False'}
# {'ID': 6030, 'is_correct': 'True'}
# {'ID': 6031, 'is_correct': 'False'}
# {'ID': 6032, 'is_correct': 'False'}
# {'ID': 6033, 'is_correct': 'False'}
# {'ID': 6034, 'is_correct': 'False'}
# {'ID': 6035, 'is_correct': 'False'}
# {'ID': 6036, 'is_correct': 'True'}
# {'ID': 6037, 'is_correct': 'True'}
# {'ID': 6038, 'is_correct': 'False'}
# {'ID': 6039, 'is_correct': 'True'}
# {'ID': 6040, 'is_correct': 'False'}
# {'ID': 6041, 'is_correct': 'False'}
# {'ID': 6042, 'is_correct': 'True'}
# {'ID': 6043, 'is_correct': 'False'}
# {'ID': 6044, 'is_correct': 'True'}
# {'ID': 6045, 'is_correct': 'True'}
# {'ID': 6046, 'is_correct': 'False'}
# {'ID': 6047, 'is_correct': 'True'}
# {'ID': 6048, 'is_correct': 'False'}
# {'ID': 6049, 'is_correct': 'True'}
# {'ID': 6050, 'is_correct': 'False'}
# {'ID': 6051, 'is_correct': 'True'}
# {'ID': 6052, 'is_correct': 'False'}
# {'ID': 6053, 'is_correct': 'True'}
# {'ID': 6054, 'is_correct': 'False'}
# {'ID': 6055, 'is_correct': 'False'}
# {'ID': 6056, 'is_correct': 'False'}
# {'ID': 6057, 'is_correct': 'False'}
# {'ID': 6058, 'is_correct': 'False'}
# {'ID': 6059, 'is_correct': 'True'}
# {'ID': 6060, 'is_correct': 'True'}
# {'ID': 6061, 'is_correct': 'True'}
# {'ID': 6062, 'is_correct': 'False'}
# {'ID': 6063, 'is_correct': 'False'}
# {'ID': 6064, 'is_correct': 'False'}
# {'ID': 6065, 'is_correct': 'True'}
# {'ID': 6066, 'is_correct': 'True'}
# {'ID': 6067, 'is_correct': 'False'}
# {'ID': 6068, 'is_correct': 'False'}
# {'ID': 6069, 'is_correct': 'False'}
# {'ID': 6070, 'is_correct': 'False'}
# {'ID': 6071, 'is_correct': 'False'}
# {'ID': 6072, 'is_correct': 'False'}
# {'ID': 6073, 'is_correct': 'False'}
# {'ID': 6074, 'is_correct': 'True'}
# {'ID': 6075, 'is_correct': 'False'}
# {'ID': 6076, 'is_correct': 'False'}
# {'ID': 6077, 'is_correct': 'False'}
# {'ID': 6078, 'is_correct': 'False'}
# {'ID': 6079, 'is_correct': 'True'}
# {'ID': 6080, 'is_correct': 'True'}
# {'ID': 6081, 'is_correct': 'True'}
# {'ID': 6082, 'is_correct': 'False'}
# {'ID': 6083, 'is_correct': 'False'}
# {'ID': 6084, 'is_correct': 'True'}
# {'ID': 6085, 'is_correct': 'False'}
# {'ID': 6086, 'is_correct': 'True'}
# {'ID': 6087, 'is_correct': 'False'}
# {'ID': 6088, 'is_correct': 'False'}
# {'ID': 6089, 'is_correct': 'True'}
# {'ID': 6090, 'is_correct': 'True'}
# {'ID': 6091, 'is_correct': 'False'}
# {'ID': 6092, 'is_correct': 'False'}
# {'ID': 6093, 'is_correct': 'True'}
# {'ID': 6094, 'is_correct': 'False'}
# {'ID': 6095, 'is_correct': 'False'}
# {'ID': 6096, 'is_correct': 'False'}
# {'ID': 6097, 'is_correct': 'False'}
# {'ID': 6098, 'is_correct': 'False'}
# {'ID': 6099, 'is_correct': 'True'}
# {'ID': 6100, 'is_correct': 'False'}
# {'ID': 6101, 'is_correct': 'False'}
# {'ID': 6102, 'is_correct': 'False'}
# {'ID': 6103, 'is_correct': 'False'}
# {'ID': 6104, 'is_correct': 'False'}
# {'ID': 6105, 'is_correct': 'False'}
# {'ID': 6106, 'is_correct': 'True'}
# {'ID': 6107, 'is_correct': 'False'}
# {'ID': 6108, 'is_correct': 'False'}
# {'ID': 6109, 'is_correct': 'False'}
# {'ID': 6110, 'is_correct': 'False'}
# {'ID': 6111, 'is_correct': 'False'}
# {'ID': 6112, 'is_correct': 'False'}
# {'ID': 6113, 'is_correct': 'False'}
# {'ID': 6114, 'is_correct': 'False'}
# {'ID': 6115, 'is_correct': 'True'}
# {'ID': 6116, 'is_correct': 'True'}
# {'ID': 6117, 'is_correct': 'False'}
# {'ID': 6118, 'is_correct': 'False'}
# {'ID': 6119, 'is_correct': 'True'}
# {'ID': 6120, 'is_correct': 'False'}
# {'ID': 6121, 'is_correct': 'True'}
# {'ID': 6122, 'is_correct': 'False'}
# {'ID': 6123, 'is_correct': 'True'}
# {'ID': 6124, 'is_correct': 'False'}
# {'ID': 6125, 'is_correct': 'False'}
# {'ID': 6126, 'is_correct': 'False'}
# {'ID': 6127, 'is_correct': 'False'}
# {'ID': 6128, 'is_correct': 'False'}
# {'ID': 6129, 'is_correct': 'False'}
# {'ID': 6130, 'is_correct': 'True'}
# {'ID': 6131, 'is_correct': 'False'}
# {'ID': 6132, 'is_correct': 'True'}
# {'ID': 6133, 'is_correct': 'False'}
# {'ID': 6134, 'is_correct': 'True'}
# {'ID': 6135, 'is_correct': 'True'}
# {'ID': 6136, 'is_correct': 'True'}
# {'ID': 6137, 'is_correct': 'False'}
# {'ID': 6138, 'is_correct': 'True'}
# {'ID': 6139, 'is_correct': 'False'}
# {'ID': 6140, 'is_correct': 'True'}
# {'ID': 6141, 'is_correct': 'False'}
# {'ID': 6142, 'is_correct': 'True'}
# {'ID': 6143, 'is_correct': 'False'}
# {'ID': 6144, 'is_correct': 'False'}
# {'ID': 6145, 'is_correct': 'False'}
# {'ID': 6146, 'is_correct': 'True'}
# {'ID': 6147, 'is_correct': 'True'}
# {'ID': 6148, 'is_correct': 'False'}
# {'ID': 6149, 'is_correct': 'False'}
# {'ID': 6150, 'is_correct': 'False'}
# {'ID': 6151, 'is_correct': 'False'}
# {'ID': 6152, 'is_correct': 'True'}
# {'ID': 6153, 'is_correct': 'False'}
# {'ID': 6154, 'is_correct': 'True'}
# {'ID': 6155, 'is_correct': 'False'}
# {'ID': 6156, 'is_correct': 'True'}
# {'ID': 6157, 'is_correct': 'True'}
# {'ID': 6158, 'is_correct': 'True'}
# {'ID': 6159, 'is_correct': 'False'}
# {'ID': 6160, 'is_correct': 'False'}
# {'ID': 6161, 'is_correct': 'True'}
# {'ID': 6162, 'is_correct': 'False'}
# {'ID': 6163, 'is_correct': 'True'}
# {'ID': 6164, 'is_correct': 'False'}
# {'ID': 6165, 'is_correct': 'False'}
# {'ID': 6166, 'is_correct': 'False'}
# {'ID': 6167, 'is_correct': 'False'}
# {'ID': 6168, 'is_correct': 'True'}
# {'ID': 6169, 'is_correct': 'True'}
# {'ID': 6170, 'is_correct': 'False'}
# {'ID': 6171, 'is_correct': 'False'}
# {'ID': 6172, 'is_correct': 'False'}
# {'ID': 6173, 'is_correct': 'False'}
# {'ID': 6174, 'is_correct': 'False'}
# {'ID': 6175, 'is_correct': 'False'}
# {'ID': 6176, 'is_correct': 'True'}
# {'ID': 6177, 'is_correct': 'False'}
# {'ID': 6178, 'is_correct': 'False'}
# {'ID': 6179, 'is_correct': 'False'}
# {'ID': 6180, 'is_correct': 'True'}
# {'ID': 6181, 'is_correct': 'True'}
# {'ID': 6182, 'is_correct': 'True'}
# {'ID': 6183, 'is_correct': 'False'}
# {'ID': 6184, 'is_correct': 'True'}
# {'ID': 6185, 'is_correct': 'False'}
# {'ID': 6186, 'is_correct': 'False'}
# {'ID': 6187, 'is_correct': 'True'}
# {'ID': 6188, 'is_correct': 'False'}
# {'ID': 6189, 'is_correct': 'True'}
# {'ID': 6190, 'is_correct': 'True'}
# {'ID': 6191, 'is_correct': 'True'}
# {'ID': 6192, 'is_correct': 'True'}
# {'ID': 6193, 'is_correct': 'False'}
# {'ID': 6194, 'is_correct': 'False'}
# {'ID': 6195, 'is_correct': 'False'}
# {'ID': 6196, 'is_correct': 'True'}
# {'ID': 6197, 'is_correct': 'False'}
# {'ID': 6198, 'is_correct': 'True'}
# {'ID': 6199, 'is_correct': 'False'}
# {'ID': 6200, 'is_correct': 'True'}
# {'ID': 6201, 'is_correct': 'False'}
# {'ID': 6202, 'is_correct': 'True'}
# {'ID': 6203, 'is_correct': 'False'}
# {'ID': 6204, 'is_correct': 'False'}
# {'ID': 6205, 'is_correct': 'False'}
# {'ID': 6206, 'is_correct': 'True'}
# {'ID': 6207, 'is_correct': 'False'}
# {'ID': 6208, 'is_correct': 'False'}
# {'ID': 6209, 'is_correct': 'False'}
# {'ID': 6210, 'is_correct': 'False'}
# {'ID': 6211, 'is_correct': 'False'}
# {'ID': 6212, 'is_correct': 'True'}
# {'ID': 6213, 'is_correct': 'True'}
# {'ID': 6214, 'is_correct': 'False'}
# {'ID': 6215, 'is_correct': 'True'}
# {'ID': 6216, 'is_correct': 'False'}
# {'ID': 6217, 'is_correct': 'False'}
# {'ID': 6218, 'is_correct': 'False'}
# {'ID': 6219, 'is_correct': 'False'}
# {'ID': 6220, 'is_correct': 'True'}
# {'ID': 6221, 'is_correct': 'False'}
# {'ID': 6222, 'is_correct': 'False'}
# {'ID': 6223, 'is_correct': 'False'}
# {'ID': 6224, 'is_correct': 'False'}
# {'ID': 6225, 'is_correct': 'False'}
# {'ID': 6226, 'is_correct': 'True'}
# {'ID': 6227, 'is_correct': 'True'}
# {'ID': 6228, 'is_correct': 'False'}
# {'ID': 6229, 'is_correct': 'False'}
# {'ID': 6230, 'is_correct': 'False'}
# {'ID': 6231, 'is_correct': 'True'}
# {'ID': 6232, 'is_correct': 'False'}
# {'ID': 6233, 'is_correct': 'True'}
# {'ID': 6234, 'is_correct': 'False'}
# {'ID': 6235, 'is_correct': 'True'}
# {'ID': 6236, 'is_correct': 'False'}
# {'ID': 6237, 'is_correct': 'True'}
# {'ID': 6238, 'is_correct': 'True'}
# {'ID': 6239, 'is_correct': 'True'}
# {'ID': 6240, 'is_correct': 'False'}
# {'ID': 6241, 'is_correct': 'False'}
# {'ID': 6242, 'is_correct': 'True'}
# {'ID': 6243, 'is_correct': 'False'}
# {'ID': 6244, 'is_correct': 'False'}
# {'ID': 6245, 'is_correct': 'False'}
# {'ID': 6246, 'is_correct': 'False'}
# {'ID': 6247, 'is_correct': 'False'}
# {'ID': 6248, 'is_correct': 'False'}
# {'ID': 6249, 'is_correct': 'True'}
# {'ID': 6250, 'is_correct': 'False'}
# {'ID': 6251, 'is_correct': 'True'}
# {'ID': 6252, 'is_correct': 'False'}
# {'ID': 6253, 'is_correct': 'False'}
# {'ID': 6254, 'is_correct': 'False'}
# {'ID': 6255, 'is_correct': 'False'}
# {'ID': 6256, 'is_correct': 'False'}
# {'ID': 6257, 'is_correct': 'False'}
# {'ID': 6258, 'is_correct': 'True'}
# {'ID': 6259, 'is_correct': 'False'}
# {'ID': 6260, 'is_correct': 'False'}
# {'ID': 6261, 'is_correct': 'True'}
# {'ID': 6262, 'is_correct': 'True'}
# {'ID': 6263, 'is_correct': 'False'}
# {'ID': 6264, 'is_correct': 'True'}
# {'ID': 6265, 'is_correct': 'False'}
# {'ID': 6266, 'is_correct': 'True'}
# {'ID': 6267, 'is_correct': 'False'}
# {'ID': 6268, 'is_correct': 'False'}
# {'ID': 6269, 'is_correct': 'True'}
# {'ID': 6270, 'is_correct': 'True'}
# {'ID': 6271, 'is_correct': 'False'}
# {'ID': 6272, 'is_correct': 'False'}
# {'ID': 6273, 'is_correct': 'True'}
# {'ID': 6274, 'is_correct': 'False'}
# {'ID': 6275, 'is_correct': 'True'}
# {'ID': 6276, 'is_correct': 'True'}
# {'ID': 6277, 'is_correct': 'False'}
# {'ID': 6278, 'is_correct': 'False'}
# {'ID': 6279, 'is_correct': 'False'}
# {'ID': 6280, 'is_correct': 'False'}
# {'ID': 6281, 'is_correct': 'True'}
# {'ID': 6282, 'is_correct': 'False'}
# {'ID': 6283, 'is_correct': 'True'}
# {'ID': 6284, 'is_correct': 'True'}
# {'ID': 6285, 'is_correct': 'True'}
# {'ID': 6286, 'is_correct': 'True'}
# {'ID': 6287, 'is_correct': 'False'}
# {'ID': 6288, 'is_correct': 'True'}
# {'ID': 6289, 'is_correct': 'False'}
# {'ID': 6290, 'is_correct': 'False'}
# {'ID': 6291, 'is_correct': 'False'}
# {'ID': 6292, 'is_correct': 'True'}
# {'ID': 6293, 'is_correct': 'True'}
# {'ID': 6294, 'is_correct': 'False'}
# {'ID': 6295, 'is_correct': 'True'}
# {'ID': 6296, 'is_correct': 'False'}
# {'ID': 6297, 'is_correct': 'False'}
# {'ID': 6298, 'is_correct': 'False'}
# {'ID': 6299, 'is_correct': 'True'}
# {'ID': 6300, 'is_correct': 'True'}
# {'ID': 6301, 'is_correct': 'True'}
# {'ID': 6302, 'is_correct': 'False'}
# {'ID': 6303, 'is_correct': 'False'}
# {'ID': 6304, 'is_correct': 'True'}
# {'ID': 6305, 'is_correct': 'False'}
# {'ID': 6306, 'is_correct': 'True'}
# {'ID': 6307, 'is_correct': 'True'}
# {'ID': 6308, 'is_correct': 'False'}
# {'ID': 6309, 'is_correct': 'False'}
# {'ID': 6310, 'is_correct': 'False'}
# {'ID': 6311, 'is_correct': 'False'}
# {'ID': 6312, 'is_correct': 'False'}
# {'ID': 6313, 'is_correct': 'False'}
# {'ID': 6314, 'is_correct': 'False'}
# {'ID': 6315, 'is_correct': 'True'}
# {'ID': 6316, 'is_correct': 'False'}
# {'ID': 6317, 'is_correct': 'False'}
# {'ID': 6318, 'is_correct': 'True'}
# {'ID': 6319, 'is_correct': 'True'}
# {'ID': 6320, 'is_correct': 'True'}
# {'ID': 6321, 'is_correct': 'False'}
# {'ID': 6322, 'is_correct': 'False'}
# {'ID': 6323, 'is_correct': 'False'}
# {'ID': 6324, 'is_correct': 'False'}
# {'ID': 6325, 'is_correct': 'False'}
# {'ID': 6326, 'is_correct': 'False'}
# {'ID': 6327, 'is_correct': 'False'}
# {'ID': 6328, 'is_correct': 'False'}
# {'ID': 6329, 'is_correct': 'True'}
# {'ID': 6330, 'is_correct': 'False'}
# {'ID': 6331, 'is_correct': 'False'}
# {'ID': 6332, 'is_correct': 'False'}
# {'ID': 6333, 'is_correct': 'False'}
# {'ID': 6334, 'is_correct': 'False'}
# {'ID': 6335, 'is_correct': 'False'}
# {'ID': 6336, 'is_correct': 'False'}
# {'ID': 6337, 'is_correct': 'False'}
# {'ID': 6338, 'is_correct': 'True'}
# {'ID': 6339, 'is_correct': 'True'}
# {'ID': 6340, 'is_correct': 'False'}
# {'ID': 6341, 'is_correct': 'False'}
# {'ID': 6342, 'is_correct': 'False'}
# ...
# {'ID': 9552, 'is_correct': 'True'}
# {'ID': 9553, 'is_correct': 'False'}
# {'ID': 9554, 'is_correct': 'False'}
# {'ID': 9555, 'is_correct': 'False'}
# {'ID': 9556, 'is_correct': 'True'}
# {'ID': 9557, 'is_correct': 'True'}
# {'ID': 9558, 'is_correct': 'False'}
# {'ID': 9559, 'is_correct': 'False'}
# {'ID': 9560, 'is_correct': 'False'}
# {'ID': 9561, 'is_correct': 'True'}
# {'ID': 9562, 'is_correct': 'False'}
# {'ID': 9563, 'is_correct': 'False'}
# {'ID': 9564, 'is_correct': 'False'}
# {'ID': 9565, 'is_correct': 'False'}
# {'ID': 9566, 'is_correct': 'False'}
# {'ID': 9567, 'is_correct': 'False'}
# {'ID': 9568, 'is_correct': 'True'}
# {'ID': 9569, 'is_correct': 'False'}
# {'ID': 9570, 'is_correct': 'True'}
# {'ID': 9571, 'is_correct': 'False'}
# {'ID': 9572, 'is_correct': 'False'}
# {'ID': 9573, 'is_correct': 'True'}
# {'ID': 9574, 'is_correct': 'False'}
# {'ID': 9575, 'is_correct': 'False'}
# {'ID': 9576, 'is_correct': 'False'}
# {'ID': 9577, 'is_correct': 'True'}
# {'ID': 9578, 'is_correct': 'True'}
# {'ID': 9579, 'is_correct': 'False'}
# {'ID': 9580, 'is_correct': 'False'}
# {'ID': 9581, 'is_correct': 'True'}
# {'ID': 9582, 'is_correct': 'False'}
# {'ID': 9583, 'is_correct': 'False'}
# {'ID': 9584, 'is_correct': 'False'}
# {'ID': 9585, 'is_correct': 'False'}
# {'ID': 9586, 'is_correct': 'False'}
# {'ID': 9587, 'is_correct': 'False'}
# {'ID': 9588, 'is_correct': 'False'}
# {'ID': 9589, 'is_correct': 'False'}
# {'ID': 9590, 'is_correct': 'False'}
# {'ID': 9591, 'is_correct': 'True'}
# {'ID': 9592, 'is_correct': 'False'}
# {'ID': 9593, 'is_correct': 'True'}
# {'ID': 9594, 'is_correct': 'True'}
# {'ID': 9595, 'is_correct': 'False'}
# {'ID': 9596, 'is_correct': 'True'}
# {'ID': 9597, 'is_correct': 'False'}
# {'ID': 9598, 'is_correct': 'False'}
# {'ID': 9599, 'is_correct': 'False'}
# {'ID': 9600, 'is_correct': 'False'}
# {'ID': 9601, 'is_correct': 'False'}
# {'ID': 9602, 'is_correct': 'True'}
# {'ID': 9603, 'is_correct': 'False'}
# {'ID': 9604, 'is_correct': 'False'}
# {'ID': 9605, 'is_correct': 'True'}
# {'ID': 9606, 'is_correct': 'False'}
# {'ID': 9607, 'is_correct': 'True'}
# {'ID': 9608, 'is_correct': 'True'}
# {'ID': 9609, 'is_correct': 'False'}
# {'ID': 9610, 'is_correct': 'False'}
# {'ID': 9611, 'is_correct': 'False'}
# {'ID': 9612, 'is_correct': 'True'}
# {'ID': 9613, 'is_correct': 'True'}
# {'ID': 9614, 'is_correct': 'False'}
# {'ID': 9615, 'is_correct': 'False'}
# {'ID': 9616, 'is_correct': 'False'}
# {'ID': 9617, 'is_correct': 'False'}
# {'ID': 9618, 'is_correct': 'False'}
# {'ID': 9619, 'is_correct': 'False'}
# {'ID': 9620, 'is_correct': 'False'}
# {'ID': 9621, 'is_correct': 'True'}
# {'ID': 9622, 'is_correct': 'False'}
# {'ID': 9623, 'is_correct': 'False'}
# {'ID': 9624, 'is_correct': 'False'}
# {'ID': 9625, 'is_correct': 'False'}
# {'ID': 9626, 'is_correct': 'False'}
# {'ID': 9627, 'is_correct': 'True'}
# {'ID': 9628, 'is_correct': 'False'}
# {'ID': 9629, 'is_correct': 'False'}
# {'ID': 9630, 'is_correct': 'False'}
# {'ID': 9631, 'is_correct': 'False'}
# {'ID': 9632, 'is_correct': 'False'}
# {'ID': 9633, 'is_correct': 'True'}
# {'ID': 9634, 'is_correct': 'True'}
# {'ID': 9635, 'is_correct': 'False'}
# {'ID': 9636, 'is_correct': 'True'}
# {'ID': 9637, 'is_correct': 'True'}
# {'ID': 9638, 'is_correct': 'True'}
# {'ID': 9639, 'is_correct': 'False'}
# {'ID': 9640, 'is_correct': 'False'}
# {'ID': 9641, 'is_correct': 'True'}
# {'ID': 9642, 'is_correct': 'True'}
# {'ID': 9643, 'is_correct': 'False'}
# {'ID': 9644, 'is_correct': 'True'}
# {'ID': 9645, 'is_correct': 'False'}
# {'ID': 9646, 'is_correct': 'False'}
# {'ID': 9647, 'is_correct': 'False'}
# {'ID': 9648, 'is_correct': 'True'}
# {'ID': 9649, 'is_correct': 'True'}
# {'ID': 9650, 'is_correct': 'True'}
# {'ID': 9651, 'is_correct': 'True'}
# {'ID': 9652, 'is_correct': 'True'}
# {'ID': 9653, 'is_correct': 'False'}
# {'ID': 9654, 'is_correct': 'False'}
# {'ID': 9655, 'is_correct': 'False'}
# {'ID': 9656, 'is_correct': 'False'}
# {'ID': 9657, 'is_correct': 'False'}
# {'ID': 9658, 'is_correct': 'False'}
# {'ID': 9659, 'is_correct': 'False'}
# {'ID': 9660, 'is_correct': 'False'}
# {'ID': 9661, 'is_correct': 'False'}
# {'ID': 9662, 'is_correct': 'True'}
# {'ID': 9663, 'is_correct': 'True'}
# {'ID': 9664, 'is_correct': 'True'}
# {'ID': 9665, 'is_correct': 'False'}
# {'ID': 9666, 'is_correct': 'False'}
# {'ID': 9667, 'is_correct': 'False'}
# {'ID': 9668, 'is_correct': 'True'}
# {'ID': 9669, 'is_correct': 'False'}
# {'ID': 9670, 'is_correct': 'True'}
# {'ID': 9671, 'is_correct': 'False'}
# {'ID': 9672, 'is_correct': 'True'}
# {'ID': 9673, 'is_correct': 'False'}
# {'ID': 9674, 'is_correct': 'False'}
# {'ID': 9675, 'is_correct': 'False'}
# {'ID': 9676, 'is_correct': 'False'}
# {'ID': 9677, 'is_correct': 'False'}
# {'ID': 9678, 'is_correct': 'False'}
# {'ID': 9679, 'is_correct': 'True'}
# {'ID': 9680, 'is_correct': 'False'}
# {'ID': 9681, 'is_correct': 'False'}
# {'ID': 9682, 'is_correct': 'False'}
# {'ID': 9683, 'is_correct': 'True'}
# {'ID': 9684, 'is_correct': 'False'}
# {'ID': 9685, 'is_correct': 'False'}
# {'ID': 9686, 'is_correct': 'False'}
# {'ID': 9687, 'is_correct': 'False'}
# {'ID': 9688, 'is_correct': 'False'}
# {'ID': 9689, 'is_correct': 'False'}
# {'ID': 9690, 'is_correct': 'True'}
# {'ID': 9691, 'is_correct': 'False'}
# {'ID': 9692, 'is_correct': 'False'}
# {'ID': 9693, 'is_correct': 'False'}
# {'ID': 9694, 'is_correct': 'False'}
# {'ID': 9695, 'is_correct': 'False'}
# {'ID': 9696, 'is_correct': 'True'}
# {'ID': 9697, 'is_correct': 'False'}
# {'ID': 9698, 'is_correct': 'False'}
# {'ID': 9699, 'is_correct': 'False'}
# {'ID': 9700, 'is_correct': 'False'}
# {'ID': 9701, 'is_correct': 'True'}
# {'ID': 9702, 'is_correct': 'True'}
# {'ID': 9703, 'is_correct': 'False'}
# {'ID': 9704, 'is_correct': 'False'}
# {'ID': 9705, 'is_correct': 'False'}
# {'ID': 9706, 'is_correct': 'True'}
# {'ID': 9707, 'is_correct': 'True'}
# {'ID': 9708, 'is_correct': 'False'}
# {'ID': 9709, 'is_correct': 'True'}
# {'ID': 9710, 'is_correct': 'False'}
# {'ID': 9711, 'is_correct': 'True'}
# {'ID': 9712, 'is_correct': 'True'}
# {'ID': 9713, 'is_correct': 'False'}
# {'ID': 9714, 'is_correct': 'False'}
# {'ID': 9715, 'is_correct': 'False'}
# {'ID': 9716, 'is_correct': 'False'}
# {'ID': 9717, 'is_correct': 'False'}
# {'ID': 9718, 'is_correct': 'False'}
# {'ID': 9719, 'is_correct': 'True'}
# {'ID': 9720, 'is_correct': 'False'}
# {'ID': 9721, 'is_correct': 'False'}
# {'ID': 9722, 'is_correct': 'True'}
# {'ID': 9723, 'is_correct': 'True'}
# {'ID': 9724, 'is_correct': 'True'}
# {'ID': 9725, 'is_correct': 'False'}
# {'ID': 9726, 'is_correct': 'True'}
# {'ID': 9727, 'is_correct': 'True'}
# {'ID': 9728, 'is_correct': 'False'}
# {'ID': 9729, 'is_correct': 'False'}
# {'ID': 9730, 'is_correct': 'False'}
# {'ID': 9731, 'is_correct': 'False'}
# {'ID': 9732, 'is_correct': 'False'}
# {'ID': 9733, 'is_correct': 'False'}
# {'ID': 9734, 'is_correct': 'False'}
# {'ID': 9735, 'is_correct': 'False'}
# {'ID': 9736, 'is_correct': 'False'}
# {'ID': 9737, 'is_correct': 'False'}
# {'ID': 9738, 'is_correct': 'True'}
# {'ID': 9739, 'is_correct': 'True'}
# {'ID': 9740, 'is_correct': 'True'}
# {'ID': 9741, 'is_correct': 'True'}
# {'ID': 9742, 'is_correct': 'False'}
# {'ID': 9743, 'is_correct': 'False'}
# {'ID': 9744, 'is_correct': 'True'}
# {'ID': 9745, 'is_correct': 'False'}
# {'ID': 9746, 'is_correct': 'False'}
# {'ID': 9747, 'is_correct': 'False'}
# {'ID': 9748, 'is_correct': 'True'}
# {'ID': 9749, 'is_correct': 'False'}
# {'ID': 9750, 'is_correct': 'False'}
# {'ID': 9751, 'is_correct': 'False'}
# {'ID': 9752, 'is_correct': 'False'}
# {'ID': 9753, 'is_correct': 'True'}
# {'ID': 9754, 'is_correct': 'False'}
# {'ID': 9755, 'is_correct': 'False'}
# {'ID': 9756, 'is_correct': 'False'}
# {'ID': 9757, 'is_correct': 'False'}
# {'ID': 9758, 'is_correct': 'False'}
# {'ID': 9759, 'is_correct': 'True'}
# {'ID': 9760, 'is_correct': 'False'}
# {'ID': 9761, 'is_correct': 'True'}
# {'ID': 9762, 'is_correct': 'False'}
# {'ID': 9763, 'is_correct': 'False'}
# {'ID': 9764, 'is_correct': 'True'}
# {'ID': 9765, 'is_correct': 'False'}
# {'ID': 9766, 'is_correct': 'True'}
# {'ID': 9767, 'is_correct': 'True'}
# {'ID': 9768, 'is_correct': 'False'}
# {'ID': 9769, 'is_correct': 'False'}
# {'ID': 9770, 'is_correct': 'False'}
# {'ID': 9771, 'is_correct': 'False'}
# {'ID': 9772, 'is_correct': 'True'}
# {'ID': 9773, 'is_correct': 'False'}
# {'ID': 9774, 'is_correct': 'False'}
# {'ID': 9775, 'is_correct': 'False'}
# {'ID': 9776, 'is_correct': 'False'}
# {'ID': 9777, 'is_correct': 'False'}
# {'ID': 9778, 'is_correct': 'True'}
# {'ID': 9779, 'is_correct': 'False'}
# {'ID': 9780, 'is_correct': 'True'}
# {'ID': 9781, 'is_correct': 'False'}
# {'ID': 9782, 'is_correct': 'True'}
# {'ID': 9783, 'is_correct': 'False'}
# {'ID': 9784, 'is_correct': 'True'}
# {'ID': 9785, 'is_correct': 'True'}
# {'ID': 9786, 'is_correct': 'False'}
# {'ID': 9787, 'is_correct': 'False'}
# {'ID': 9788, 'is_correct': 'False'}
# {'ID': 9789, 'is_correct': 'False'}
# {'ID': 9790, 'is_correct': 'False'}
# {'ID': 9791, 'is_correct': 'True'}
# {'ID': 9792, 'is_correct': 'False'}
# {'ID': 9793, 'is_correct': 'False'}
# {'ID': 9794, 'is_correct': 'False'}
# {'ID': 9795, 'is_correct': 'False'}
# {'ID': 9796, 'is_correct': 'True'}
# {'ID': 9797, 'is_correct': 'False'}
# {'ID': 9798, 'is_correct': 'False'}
# {'ID': 9799, 'is_correct': 'False'}
# {'ID': 9800, 'is_correct': 'True'}
# {'ID': 9801, 'is_correct': 'False'}
# {'ID': 9802, 'is_correct': 'False'}
# {'ID': 9803, 'is_correct': 'False'}
# {'ID': 9804, 'is_correct': 'True'}
# {'ID': 9805, 'is_correct': 'False'}
# {'ID': 9806, 'is_correct': 'False'}
# {'ID': 9807, 'is_correct': 'False'}
# {'ID': 9808, 'is_correct': 'True'}
# {'ID': 9809, 'is_correct': 'False'}
# {'ID': 9810, 'is_correct': 'True'}
# {'ID': 9811, 'is_correct': 'False'}
# {'ID': 9812, 'is_correct': 'False'}
# {'ID': 9813, 'is_correct': 'False'}
# {'ID': 9814, 'is_correct': 'False'}
# {'ID': 9815, 'is_correct': 'True'}
# {'ID': 9816, 'is_correct': 'False'}
# {'ID': 9817, 'is_correct': 'False'}
# {'ID': 9818, 'is_correct': 'False'}
# {'ID': 9819, 'is_correct': 'False'}
# {'ID': 9820, 'is_correct': 'False'}
# {'ID': 9821, 'is_correct': 'True'}
# {'ID': 9822, 'is_correct': 'True'}
# {'ID': 9823, 'is_correct': 'True'}
# {'ID': 9824, 'is_correct': 'True'}
# {'ID': 9825, 'is_correct': 'False'}
# {'ID': 9826, 'is_correct': 'True'}
# {'ID': 9827, 'is_correct': 'False'}
# {'ID': 9828, 'is_correct': 'True'}
# {'ID': 9829, 'is_correct': 'True'}
# {'ID': 9830, 'is_correct': 'False'}
# {'ID': 9831, 'is_correct': 'False'}
# {'ID': 9832, 'is_correct': 'False'}
# {'ID': 9833, 'is_correct': 'False'}
# {'ID': 9834, 'is_correct': 'False'}
# {'ID': 9835, 'is_correct': 'False'}
# {'ID': 9836, 'is_correct': 'False'}
# {'ID': 9837, 'is_correct': 'True'}
# {'ID': 9838, 'is_correct': 'False'}
# {'ID': 9839, 'is_correct': 'False'}
# {'ID': 9840, 'is_correct': 'False'}
# {'ID': 9841, 'is_correct': 'False'}
# {'ID': 9842, 'is_correct': 'True'}
# {'ID': 9843, 'is_correct': 'True'}
# {'ID': 9844, 'is_correct': 'True'}
# {'ID': 9845, 'is_correct': 'False'}
# {'ID': 9846, 'is_correct': 'True'}
# {'ID': 9847, 'is_correct': 'True'}
# {'ID': 9848, 'is_correct': 'False'}
# {'ID': 9849, 'is_correct': 'False'}
# {'ID': 9850, 'is_correct': 'False'}
# {'ID': 9851, 'is_correct': 'False'}
# {'ID': 9852, 'is_correct': 'True'}
# {'ID': 9853, 'is_correct': 'True'}
# {'ID': 9854, 'is_correct': 'False'}
# {'ID': 9855, 'is_correct': 'True'}
# {'ID': 9856, 'is_correct': 'True'}
# {'ID': 9857, 'is_correct': 'False'}
# {'ID': 9858, 'is_correct': 'False'}
# {'ID': 9859, 'is_correct': 'True'}
# {'ID': 9860, 'is_correct': 'False'}
# {'ID': 9861, 'is_correct': 'False'}
# {'ID': 9862, 'is_correct': 'True'}
# {'ID': 9863, 'is_correct': 'False'}
# {'ID': 9864, 'is_correct': 'False'}
# {'ID': 9865, 'is_correct': 'False'}
# {'ID': 9866, 'is_correct': 'False'}
# {'ID': 9867, 'is_correct': 'False'}
# {'ID': 9868, 'is_correct': 'False'}
# {'ID': 9869, 'is_correct': 'False'}
# {'ID': 9870, 'is_correct': 'False'}
# {'ID': 9871, 'is_correct': 'True'}
# {'ID': 9872, 'is_correct': 'False'}
# {'ID': 9873, 'is_correct': 'False'}
# {'ID': 9874, 'is_correct': 'False'}
# {'ID': 9875, 'is_correct': 'False'}
# {'ID': 9876, 'is_correct': 'True'}
# {'ID': 9877, 'is_correct': 'False'}
# {'ID': 9878, 'is_correct': 'False'}
# {'ID': 9879, 'is_correct': 'False'}
# {'ID': 9880, 'is_correct': 'False'}
# {'ID': 9881, 'is_correct': 'True'}
# {'ID': 9882, 'is_correct': 'False'}
# {'ID': 9883, 'is_correct': 'False'}
# {'ID': 9884, 'is_correct': 'False'}
# {'ID': 9885, 'is_correct': 'False'}
# {'ID': 9886, 'is_correct': 'False'}
# {'ID': 9887, 'is_correct': 'False'}
# {'ID': 9888, 'is_correct': 'True'}
# {'ID': 9889, 'is_correct': 'False'}
# {'ID': 9890, 'is_correct': 'True'}
# {'ID': 9891, 'is_correct': 'True'}
# {'ID': 9892, 'is_correct': 'False'}
# {'ID': 9893, 'is_correct': 'True'}
# {'ID': 9894, 'is_correct': 'True'}
# {'ID': 9895, 'is_correct': 'False'}
# {'ID': 9896, 'is_correct': 'True'}
# {'ID': 9897, 'is_correct': 'True'}
# {'ID': 9898, 'is_correct': 'False'}
# {'ID': 9899, 'is_correct': 'True'}
# {'ID': 9900, 'is_correct': 'True'}
# {'ID': 9901, 'is_correct': 'False'}
# {'ID': 9902, 'is_correct': 'True'}
# {'ID': 9903, 'is_correct': 'True'}
# {'ID': 9904, 'is_correct': 'False'}
# {'ID': 9905, 'is_correct': 'False'}
# {'ID': 9906, 'is_correct': 'False'}
# {'ID': 9907, 'is_correct': 'False'}
# {'ID': 9908, 'is_correct': 'False'}
# {'ID': 9909, 'is_correct': 'False'}
# {'ID': 9910, 'is_correct': 'False'}
# {'ID': 9911, 'is_correct': 'False'}
# {'ID': 9912, 'is_correct': 'True'}
# {'ID': 9913, 'is_correct': 'False'}
# {'ID': 9914, 'is_correct': 'False'}
# {'ID': 9915, 'is_correct': 'True'}
# {'ID': 9916, 'is_correct': 'False'}
# {'ID': 9917, 'is_correct': 'False'}
# {'ID': 9918, 'is_correct': 'False'}
# {'ID': 9919, 'is_correct': 'True'}
# {'ID': 9920, 'is_correct': 'True'}
# {'ID': 9921, 'is_correct': 'True'}
# {'ID': 9922, 'is_correct': 'False'}
# {'ID': 9923, 'is_correct': 'False'}
# {'ID': 9924, 'is_correct': 'True'}
# {'ID': 9925, 'is_correct': 'False'}
# {'ID': 9926, 'is_correct': 'False'}
# {'ID': 9927, 'is_correct': 'False'}
# {'ID': 9928, 'is_correct': 'False'}
# {'ID': 9929, 'is_correct': 'False'}
# {'ID': 9930, 'is_correct': 'False'}
# {'ID': 9931, 'is_correct': 'True'}
# {'ID': 9932, 'is_correct': 'True'}
# {'ID': 9933, 'is_correct': 'False'}
# {'ID': 9934, 'is_correct': 'False'}
# {'ID': 9935, 'is_correct': 'False'}
# {'ID': 9936, 'is_correct': 'True'}
# {'ID': 9937, 'is_correct': 'True'}
# {'ID': 9938, 'is_correct': 'False'}
# {'ID': 9939, 'is_correct': 'False'}
# {'ID': 9940, 'is_correct': 'False'}
# {'ID': 9941, 'is_correct': 'True'}
# {'ID': 9942, 'is_correct': 'True'}
# {'ID': 9943, 'is_correct': 'True'}
# {'ID': 9944, 'is_correct': 'False'}
# {'ID': 9945, 'is_correct': 'False'}
# {'ID': 9946, 'is_correct': 'False'}
# {'ID': 9947, 'is_correct': 'True'}
# {'ID': 9948, 'is_correct': 'False'}
# {'ID': 9949, 'is_correct': 'False'}
# {'ID': 9950, 'is_correct': 'True'}
# {'ID': 9951, 'is_correct': 'False'}
# {'ID': 9952, 'is_correct': 'False'}
# {'ID': 9953, 'is_correct': 'False'}
# {'ID': 9954, 'is_correct': 'True'}
# {'ID': 9955, 'is_correct': 'True'}
# {'ID': 9956, 'is_correct': 'False'}
# {'ID': 9957, 'is_correct': 'False'}
# {'ID': 9958, 'is_correct': 'True'}
# {'ID': 9959, 'is_correct': 'False'}
# {'ID': 9960, 'is_correct': 'False'}
# {'ID': 9961, 'is_correct': 'True'}
# {'ID': 9962, 'is_correct': 'False'}
# {'ID': 9963, 'is_correct': 'True'}
# {'ID': 9964, 'is_correct': 'False'}
# {'ID': 9965, 'is_correct': 'False'}
# {'ID': 9966, 'is_correct': 'False'}
# {'ID': 9967, 'is_correct': 'False'}
# {'ID': 9968, 'is_correct': 'False'}
# {'ID': 9969, 'is_correct': 'True'}
# {'ID': 9970, 'is_correct': 'False'}
# {'ID': 9971, 'is_correct': 'True'}
# {'ID': 9972, 'is_correct': 'False'}
# {'ID': 9973, 'is_correct': 'True'}
# {'ID': 9974, 'is_correct': 'False'}
# {'ID': 9975, 'is_correct': 'False'}
# {'ID': 9976, 'is_correct': 'True'}
# {'ID': 9977, 'is_correct': 'False'}
# {'ID': 9978, 'is_correct': 'True'}
# {'ID': 9979, 'is_correct': 'True'}
# {'ID': 9980, 'is_correct': 'True'}
# {'ID': 9981, 'is_correct': 'True'}
# {'ID': 9982, 'is_correct': 'True'}
# {'ID': 9983, 'is_correct': 'False'}
# {'ID': 9984, 'is_correct': 'True'}
# {'ID': 9985, 'is_correct': 'False'}
# {'ID': 9986, 'is_correct': 'True'}
# {'ID': 9987, 'is_correct': 'True'}
# {'ID': 9988, 'is_correct': 'False'}
# {'ID': 9989, 'is_correct': 'False'}
# {'ID': 9990, 'is_correct': 'False'}
# {'ID': 9991, 'is_correct': 'True'}
# {'ID': 9992, 'is_correct': 'True'}
# {'ID': 9993, 'is_correct': 'False'}
# {'ID': 9994, 'is_correct': 'False'}
# {'ID': 9995, 'is_correct': 'True'}
# {'ID': 9996, 'is_correct': 'False'}
# {'ID': 9997, 'is_correct': 'True'}
# {'ID': 9998, 'is_correct': 'False'}
# {'ID': 9999, 'is_correct': 'False'}

# %%
import pandas as pd

# 将结果保存为 CSV 文件
df = pd.DataFrame(results)
df.to_csv('test_set_predictions.csv', index=False)

print("全量测试集推理完成，结果已保存为 'test_set_predictions.csv'")
# Out:
# 全量测试集推理完成，结果已保存为 'test_set_predictions.csv'

# %% [markdown]
# ## saving model

# %%
model.save_pretrained("lora_model") # Local saving
tokenizer.save_pretrained("lora_model")
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.json')

# %%
if True:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference
# Out:
# ==((====))==  Unsloth 2024.11.6: Fast Llama patching. Transformers = 4.46.2.
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.564 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.1+cu124. CUDA = 8.0. CUDA Toolkit = 12.4.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
# !zip -r lora_model.zip lora_model
# Out:
#   adding: lora_model/ (stored 0%)
#   adding: lora_model/tokenizer.json (deflated 85%)
#   adding: lora_model/README.md (deflated 66%)
#   adding: lora_model/tokenizer_config.json (deflated 96%)
#   adding: lora_model/adapter_config.json (deflated 54%)
#   adding: lora_model/special_tokens_map.json (deflated 71%)
#   adding: lora_model/adapter_model.safetensors (deflated 7%)
